# %% [markdown]
# - **Student's Names:** Elham Jangravi, Parisa Khanjani Malayeri, Ahmad Bahmani, Zavash Ghorbanpourbaboli
# - **Course:** CS550 Big Data Management and Analytics

# %%
import pprint
# !pip install pyspark
from pyspark.sql import SparkSession
import random
import numpy as np
import math
import hashlib
import csv

spark = SparkSession.builder.master("local[*]").getOrCreate()

hospital_data_trial = spark.sparkContext.textFile('./trial_COVID-19_Hospital_Impact.csv', 32)
hospital_data_test = spark.sparkContext.textFile('./test_COVID-19_Hospital_Impact.csv', 32)

# %% [markdown]
# # Tasks
# ## A. Extract binary features
# - Extract binary features (i.e., a sparse representation of the characteristic matrix) per hospital.

# %% [markdown]
# **Checkpoint A:**
# We employ the combination of `csvreader` and `mapPartitions` for effectively transforming each data row into an array format. This process involves storing the header in a broadcast variable, which facilitates the mapping of each row to its corresponding header name. Additionally, we utilize a set union within a `reduceByKey` function. This method is critical for amalgamating various rows associated with a singular hospital pk, resulting in a consolidated RDD record.

# %%
hospital_data_trial = hospital_data_trial.mapPartitions(lambda y: map(lambda line: line.split(','), y))
bc = spark.sparkContext.broadcast(hospital_data_trial.take(1))

hospital_data_trial = hospital_data_trial.filter(lambda row: row != bc.value)
hospital_data_trial = hospital_data_trial.mapPartitions(
    lambda y: map(
        lambda x: (x[0], set([f'{b}:{a}' for a, b in zip(x, bc.value[0])])), y
        )
    ).reduceByKey(lambda x, y: x.union(y))
length = hospital_data_trial.count()

Checkpoint_A = ['150034', '050739', '330231', '241326', '070008']
pks = hospital_data_trial.filter(lambda x: x[0] in Checkpoint_A)

print('Start_____Task A_____Trail_____Data_____')
task_a_Print = pprint.PrettyPrinter(width=150, compact=True, depth = 3)
Task_A_Print.pprint(pks.collect())
print('End_____Task A_____Trail_____Data_____')
# Out:
# Start_____Task A_____Trail _____Data_____
# [Stage 36:======================================>                 (22 + 8) / 32]
# [('070008',
#   {'address:201 CHESTNUT HILL ROAD', 'all_adult_hospital_beds_7_day_avg:65.6', 'all_adult_hospital_beds_7_day_coverage:7',
#    'all_adult_hospital_beds_7_day_sum:459', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:221',
#    'all_adult_hospital_inpatient_beds_7_day_avg:60.3', 'all_adult_hospital_inpatient_beds_7_day_coverage:7',
#    'all_adult_hospital_inpatient_beds_7_day_sum:422', 'ccn:070008', 'city:STAFFORD SPRINGS', 'collection_week:2020/07/31', 'fips_code:09013',
#    'geocoded_hospital_address:', 'hhs_ids:[C070008-A]', 'hospital_name:JOHNSON MEMORIAL HOSPITAL', 'hospital_pk:070008',
#    'hospital_subtype:Short Term', 'icu_beds_used_7_day_avg:-999999', 'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:16',
#    'icu_patients_confirmed_influenza_7_day_avg:', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'icu_patients_confirmed_influenza_7_day_sum:',
#    'inpatient_beds_7_day_avg:60.3', 'inpatient_beds_7_day_coverage:7', 'inpatient_beds_7_day_sum:422', 'inpatient_beds_used_7_day_avg:31.6',
#    'inpatient_beds_used_7_day_coverage:7', 'inpatient_beds_used_7_day_sum:221', 'inpatient_beds_used_covid_7_day_avg:-999999',
#    'inpatient_beds_used_covid_7_day_coverage:7', 'inpatient_beds_used_covid_7_day_sum:4', 'is_corrected:false', 'is_metro_micro:true',
#    'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:6',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_7_day_coverage:6', 'previous_day_admission_adult_covid_suspected_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:-999999',
#    'previous_day_admission_influenza_confirmed_7_day_sum:', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:6',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:5',
#    'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'previous_day_covid_ED_visits_7_day_sum:18',
#    'previous_day_total_ED_visits_7_day_sum:323', 'previous_week_patients_covid_vaccinated_doses_all_7_day:',
#    'previous_week_patients_covid_vaccinated_doses_one_7_day:', 'previous_week_personnel_covid_vaccinated_doses_administered_7_day:',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:-999999', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:16', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'state:CT',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:4', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:0',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:0',
#    'total_beds_7_day_avg:65.6', 'total_beds_7_day_coverage:7', 'total_beds_7_day_sum:459', 'total_icu_beds_7_day_avg:7',
#    'total_icu_beds_7_day_coverage:6', 'total_icu_beds_7_day_sum:42', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_coverage:0', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_personnel_covid_vaccinated_doses_all_7_day:',
#    'total_personnel_covid_vaccinated_doses_none_7_day:', 'total_personnel_covid_vaccinated_doses_one_7_day:',
#    'total_staffed_adult_icu_beds_7_day_avg:7', 'total_staffed_adult_icu_beds_7_day_coverage:6', 'total_staffed_adult_icu_beds_7_day_sum:42',
#    'zip:06076'}),
#  ('241326',
#   {'address:50 CENTRACARE DRIVE', 'all_adult_hospital_beds_7_day_avg:22', 'all_adult_hospital_beds_7_day_coverage:7',
#    'all_adult_hospital_beds_7_day_sum:154', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:4.3',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:30',
#    'all_adult_hospital_inpatient_beds_7_day_avg:14', 'all_adult_hospital_inpatient_beds_7_day_coverage:7',
#    'all_adult_hospital_inpatient_beds_7_day_sum:98', 'ccn:241326', 'city:LONG PRAIRIE', 'collection_week:2020/08/07', 'fips_code:27153',
#    'geocoded_hospital_address:', 'hhs_ids:[C241326-A]', 'hospital_name:CENTRACARE HEALTH SYSTEM - LONG PRAIRIE', 'hospital_pk:241326',
#    'hospital_subtype:Critical Access Hospitals', 'icu_beds_used_7_day_avg:0', 'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:0',
#    'icu_patients_confirmed_influenza_7_day_avg:', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'icu_patients_confirmed_influenza_7_day_sum:',
#    'inpatient_beds_7_day_avg:14', 'inpatient_beds_7_day_coverage:7', 'inpatient_beds_7_day_sum:98', 'inpatient_beds_used_7_day_avg:5.1',
#    'inpatient_beds_used_7_day_coverage:7', 'inpatient_beds_used_7_day_sum:36', 'inpatient_beds_used_covid_7_day_avg:0',
#    'inpatient_beds_used_covid_7_day_coverage:7', 'inpatient_beds_used_covid_7_day_sum:0', 'is_corrected:false', 'is_metro_micro:false',
#    'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:0',
#    'previous_day_admission_influenza_confirmed_7_day_sum:', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'previous_day_covid_ED_visits_7_day_sum:15',
#    'previous_day_total_ED_visits_7_day_sum:92', 'previous_week_patients_covid_vaccinated_doses_all_7_day:',
#    'previous_week_patients_covid_vaccinated_doses_one_7_day:', 'previous_week_personnel_covid_vaccinated_doses_administered_7_day:',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:0', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'staffed_adult_icu_bed_occupancy_7_day_sum:0',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'state:MN',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:0',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:0',
#    'total_beds_7_day_avg:22', 'total_beds_7_day_coverage:7', 'total_beds_7_day_sum:154', 'total_icu_beds_7_day_avg:0',
#    'total_icu_beds_7_day_coverage:7', 'total_icu_beds_7_day_sum:0', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_coverage:0', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_personnel_covid_vaccinated_doses_all_7_day:',
#    'total_personnel_covid_vaccinated_doses_none_7_day:', 'total_personnel_covid_vaccinated_doses_one_7_day:',
#    'total_staffed_adult_icu_beds_7_day_avg:0', 'total_staffed_adult_icu_beds_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_sum:0',
#    'zip:56347'}),
#  ('150034',
#   {'address:1500 S LAKE PARK AVE', 'all_adult_hospital_beds_7_day_avg:218', 'all_adult_hospital_beds_7_day_coverage:7',
#    'all_adult_hospital_beds_7_day_sum:1526', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:145.3',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:158.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1017', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1110',
#    'all_adult_hospital_inpatient_beds_7_day_avg:218', 'all_adult_hospital_inpatient_beds_7_day_coverage:7',
#    'all_adult_hospital_inpatient_beds_7_day_sum:1526', 'ccn:150034', 'city:HOBART', 'collection_week:2020/08/14', 'collection_week:2021/01/22',
#    'fips_code:18089', 'geocoded_hospital_address:POINT (-87.258916 41.513396)', 'hhs_ids:[C150034-A]', 'hospital_name:ST MARY MEDICAL CENTER INC',
#    'hospital_pk:150034', 'hospital_subtype:Short Term', 'icu_beds_used_7_day_avg:16', 'icu_beds_used_7_day_avg:16.3',
#    'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:112', 'icu_beds_used_7_day_sum:114', 'icu_patients_confirmed_influenza_7_day_avg:',
#    'icu_patients_confirmed_influenza_7_day_avg:0', 'icu_patients_confirmed_influenza_7_day_coverage:0',
#    'icu_patients_confirmed_influenza_7_day_coverage:7', 'icu_patients_confirmed_influenza_7_day_sum:', 'icu_patients_confirmed_influenza_7_day_sum:0',
#    'inpatient_beds_7_day_avg:218', 'inpatient_beds_7_day_coverage:7', 'inpatient_beds_7_day_sum:1526', 'inpatient_beds_used_7_day_avg:145.3',
#    'inpatient_beds_used_7_day_avg:158.6', 'inpatient_beds_used_7_day_coverage:7', 'inpatient_beds_used_7_day_sum:1017',
#    'inpatient_beds_used_7_day_sum:1110', 'inpatient_beds_used_covid_7_day_avg:11.9', 'inpatient_beds_used_covid_7_day_avg:22.7',
#    'inpatient_beds_used_covid_7_day_coverage:7', 'inpatient_beds_used_covid_7_day_sum:159', 'inpatient_beds_used_covid_7_day_sum:83',
#    'is_corrected:false', 'is_metro_micro:true', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:5', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:14', 'previous_day_admission_adult_covid_confirmed_7_day_sum:7',
#    'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:8', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:10', 'previous_day_admission_adult_covid_suspected_7_day_coverage:7',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_7_day_sum:30',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:5',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:0', 'previous_day_admission_influenza_confirmed_7_day_sum:',
#    'previous_day_admission_influenza_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_sum:-999999', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0',
#    'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7', 'previous_day_admission_pediatric_covid_suspected_7_day_sum:0',
#    'previous_day_covid_ED_visits_7_day_sum:129', 'previous_day_covid_ED_visits_7_day_sum:29', 'previous_day_total_ED_visits_7_day_sum:519',
#    'previous_day_total_ED_visits_7_day_sum:639', 'previous_week_patients_covid_vaccinated_doses_all_7_day:',
#    'previous_week_patients_covid_vaccinated_doses_one_7_day:', 'previous_week_personnel_covid_vaccinated_doses_administered_7_day:',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:16', 'staffed_adult_icu_bed_occupancy_7_day_avg:16.3',
#    'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'staffed_adult_icu_bed_occupancy_7_day_sum:112',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:114', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:4.9',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:25', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:34',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_avg:-999999', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.9',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:25',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:34', 'state:IN',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:11.9',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:22.7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:159',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:83', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:22.6',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:8.1', 'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:158', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:57',
#    'total_beds_7_day_avg:288', 'total_beds_7_day_coverage:7', 'total_beds_7_day_sum:2016', 'total_icu_beds_7_day_avg:20',
#    'total_icu_beds_7_day_coverage:7', 'total_icu_beds_7_day_sum:140', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_avg:0', 'total_patients_hospitalized_confirmed_influenza_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_7_day_coverage:7', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_sum:0', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:7',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_personnel_covid_vaccinated_doses_all_7_day:',
#    'total_personnel_covid_vaccinated_doses_none_7_day:', 'total_personnel_covid_vaccinated_doses_one_7_day:',
#    'total_staffed_adult_icu_beds_7_day_avg:20', 'total_staffed_adult_icu_beds_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_sum:140',
#    'zip:46342'}),
#  ('050739',
#   {'address:555 EAST HARDY STREET', 'all_adult_hospital_beds_7_day_avg:272.9', 'all_adult_hospital_beds_7_day_coverage:7',
#    'all_adult_hospital_beds_7_day_sum:1910', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:167.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1173',
#    'all_adult_hospital_inpatient_beds_7_day_avg:220.9', 'all_adult_hospital_inpatient_beds_7_day_coverage:7',
#    'all_adult_hospital_inpatient_beds_7_day_sum:1546', 'ccn:050739', 'city:INGLEWOOD', 'collection_week:2021/04/16', 'fips_code:06037',
#    'geocoded_hospital_address:POINT (-118.347779 33.949085)', 'hhs_ids:[C050739-A]', 'hospital_name:CENTINELA HOSPITAL MEDICAL CENTER',
#    'hospital_pk:050739', 'hospital_subtype:Short Term', 'icu_beds_used_7_day_avg:25', 'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:175',
#    'icu_patients_confirmed_influenza_7_day_avg:0', 'icu_patients_confirmed_influenza_7_day_coverage:7',
#    'icu_patients_confirmed_influenza_7_day_sum:0', 'inpatient_beds_7_day_avg:224.7', 'inpatient_beds_7_day_coverage:7',
#    'inpatient_beds_7_day_sum:1573', 'inpatient_beds_used_7_day_avg:171.4', 'inpatient_beds_used_7_day_coverage:7',
#    'inpatient_beds_used_7_day_sum:1200', 'inpatient_beds_used_covid_7_day_avg:4.4', 'inpatient_beds_used_covid_7_day_coverage:7',
#    'inpatient_beds_used_covid_7_day_sum:31', 'is_corrected:false', 'is_metro_micro:true',
#    'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:5', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:6', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:6',
#    'previous_day_admission_adult_covid_suspected_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:21',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:0',
#    'previous_day_admission_influenza_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'previous_day_covid_ED_visits_7_day_sum:30',
#    'previous_day_total_ED_visits_7_day_sum:1169', 'previous_week_patients_covid_vaccinated_doses_all_7_day:0',
#    'previous_week_patients_covid_vaccinated_doses_one_7_day:0', 'previous_week_personnel_covid_vaccinated_doses_administered_7_day:0',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:21.1', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:148', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:4', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'state:CA',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:4.4',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:31',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:-999999', 'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'total_beds_7_day_avg:276.7', 'total_beds_7_day_coverage:7',
#    'total_beds_7_day_sum:1937', 'total_icu_beds_7_day_avg:36.4', 'total_icu_beds_7_day_coverage:7', 'total_icu_beds_7_day_sum:255',
#    'total_patients_hospitalized_confirmed_influenza_7_day_avg:0', 'total_patients_hospitalized_confirmed_influenza_7_day_coverage:7',
#    'total_patients_hospitalized_confirmed_influenza_7_day_sum:0', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:7',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_personnel_covid_vaccinated_doses_all_7_day:2362',
#    'total_personnel_covid_vaccinated_doses_none_7_day:679', 'total_personnel_covid_vaccinated_doses_one_7_day:258',
#    'total_staffed_adult_icu_beds_7_day_avg:32.6', 'total_staffed_adult_icu_beds_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_sum:228',
#    'zip:90301'}),
#  ('330231',
#   {'address:82-68 164TH STREET', 'all_adult_hospital_beds_7_day_avg:1045.9', 'all_adult_hospital_beds_7_day_coverage:7',
#    'all_adult_hospital_beds_7_day_sum:7321', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:146.1',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1023',
#    'all_adult_hospital_inpatient_beds_7_day_avg:334.9', 'all_adult_hospital_inpatient_beds_7_day_coverage:7',
#    'all_adult_hospital_inpatient_beds_7_day_sum:2344', 'ccn:330231', 'city:JAMAICA', 'collection_week:2020/10/30', 'fips_code:36081',
#    'geocoded_hospital_address:POINT (-73.803448 40.717037)', 'hhs_ids:[C330231-A]', 'hospital_name:QUEENS HOSPITAL CENTER', 'hospital_pk:330231',
#    'hospital_subtype:Short Term', 'icu_beds_used_7_day_avg:28.3', 'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:198',
#    'icu_patients_confirmed_influenza_7_day_avg:', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'icu_patients_confirmed_influenza_7_day_sum:',
#    'inpatient_beds_7_day_avg:334.9', 'inpatient_beds_7_day_coverage:7', 'inpatient_beds_7_day_sum:2344', 'inpatient_beds_used_7_day_avg:146.1',
#    'inpatient_beds_used_7_day_coverage:7', 'inpatient_beds_used_7_day_sum:1023', 'inpatient_beds_used_covid_7_day_avg:8.1',
#    'inpatient_beds_used_covid_7_day_coverage:7', 'inpatient_beds_used_covid_7_day_sum:57', 'is_corrected:false', 'is_metro_micro:true',
#    'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:6',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:6',
#    'previous_day_admission_influenza_confirmed_7_day_sum:', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'previous_day_covid_ED_visits_7_day_sum:12',
#    'previous_day_total_ED_visits_7_day_sum:1213', 'previous_week_patients_covid_vaccinated_doses_all_7_day:',
#    'previous_week_patients_covid_vaccinated_doses_one_7_day:', 'previous_week_personnel_covid_vaccinated_doses_administered_7_day:',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:15', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:105', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:-999999', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:-999999',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:-999999', 'state:NY',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:8.1',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:57', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:5.7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:40',
#    'total_beds_7_day_avg:1045.9', 'total_beds_7_day_coverage:7', 'total_beds_7_day_sum:7321', 'total_icu_beds_7_day_avg:28.9',
#    'total_icu_beds_7_day_coverage:7', 'total_icu_beds_7_day_sum:202', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_coverage:0', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_personnel_covid_vaccinated_doses_all_7_day:',
#    'total_personnel_covid_vaccinated_doses_none_7_day:', 'total_personnel_covid_vaccinated_doses_one_7_day:',
#    'total_staffed_adult_icu_beds_7_day_avg:28', 'total_staffed_adult_icu_beds_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_sum:196',
#    'zip:11432'})]
# End_____Task A_____Trail_____Data_____

# %%
hospital_data_test = hospital_data_test.mapPartitions(lambda y: map(lambda line: line.split(','), y))
bc = spark.sparkContext.broadcast(hospital_data_test.take(1))

hospital_data_test = hospital_data_test.filter(lambda row: row != bc.value)
hospital_data_test = hospital_data_test.mapPartitions(
    lambda y: map(
        lambda x: (x[0], set([f'{b}:{a}' for a, b in zip(x, bc.value[0])])), y
        )
    ).reduceByKey(lambda x, y: x.union(y))
length = hospital_data_test.count()

Checkpoint_A = ['150034', '050739', '330231', '241326', '070008']
pks = hospital_data_test.filter(lambda x: x[0] in Checkpoint_A)

print('Start_____Task A_____Test_____Data_____')
task_a_Print = pprint.PrettyPrinter(width=150, compact=True, depth = 3)
Task_A_Print.pprint(pks.collect())
print('End_____Task A_____Test_____Data_____')
# Out:
# Start_____Task A_____Test _____Data_____
# [Stage 41:===============================================>        (27 + 5) / 32]
# [('070008',
#   {'address:201 CHESTNUT HILL ROAD', 'all_adult_hospital_beds_7_day_avg:49.3', 'all_adult_hospital_beds_7_day_avg:50.7',
#    'all_adult_hospital_beds_7_day_avg:54.6', 'all_adult_hospital_beds_7_day_avg:55', 'all_adult_hospital_beds_7_day_avg:56.9',
#    'all_adult_hospital_beds_7_day_avg:60.3', 'all_adult_hospital_beds_7_day_avg:65.6', 'all_adult_hospital_beds_7_day_avg:68',
#    'all_adult_hospital_beds_7_day_coverage:6', 'all_adult_hospital_beds_7_day_coverage:7', 'all_adult_hospital_beds_7_day_sum:330',
#    'all_adult_hospital_beds_7_day_sum:345', 'all_adult_hospital_beds_7_day_sum:355', 'all_adult_hospital_beds_7_day_sum:382',
#    'all_adult_hospital_beds_7_day_sum:385', 'all_adult_hospital_beds_7_day_sum:398', 'all_adult_hospital_beds_7_day_sum:422',
#    'all_adult_hospital_beds_7_day_sum:459', 'all_adult_hospital_beds_7_day_sum:476', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:23.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:23.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:24',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:25.1', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:25.9',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:26', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:26.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:27.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:27.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:28', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:28.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:28.7', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.1', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.3',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.4', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.7', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:29.9',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.1',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:30.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.1', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.3',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.4', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.6',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.1',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:32.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:33',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:33.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:33.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:33.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.1',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:35',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:35.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:35.4',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:35.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:36.1',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:36.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:36.7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:37', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:37.9',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_avg:38', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:39.7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:6', 'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:164', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:167',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:168', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:176',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:181', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:182',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:185', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:191',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:193', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:196',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:200', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:201',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:203', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:204',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:205', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:206',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:207', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:208',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:209', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:210',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:211', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:213',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:214', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:215',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:216', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:217',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:218', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:219',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:220', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:221',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:223', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:225',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:226', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:227',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:228', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:229',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:230', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:231',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:233', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:234',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:235', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:239',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:240', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:241',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:242', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:243',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:244', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:245',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:247', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:248',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:251', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:253',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:254', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:257',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:259', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:265',
#    'all_adult_hospital_inpatient_bed_occupied_7_day_sum:266', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:278',
#    'all_adult_hospital_inpatient_beds_7_day_avg:47.9', 'all_adult_hospital_inpatient_beds_7_day_avg:48.1',
#    'all_adult_hospital_inpatient_beds_7_day_avg:49.3', 'all_adult_hospital_inpatient_beds_7_day_avg:50.1',
#    'all_adult_hospital_inpatient_beds_7_day_avg:52', 'all_adult_hospital_inpatient_beds_7_day_avg:55',
#    'all_adult_hospital_inpatient_beds_7_day_avg:60.3', 'all_adult_hospital_inpatient_beds_7_day_coverage:6',
#    'all_adult_hospital_inpatient_beds_7_day_coverage:7', 'all_adult_hospital_inpatient_beds_7_day_sum:330',
#    'all_adult_hospital_inpatient_beds_7_day_sum:335', 'all_adult_hospital_inpatient_beds_7_day_sum:337',
#    'all_adult_hospital_inpatient_beds_7_day_sum:345', 'all_adult_hospital_inpatient_beds_7_day_sum:351',
#    'all_adult_hospital_inpatient_beds_7_day_sum:364', 'all_adult_hospital_inpatient_beds_7_day_sum:385',
#    'all_adult_hospital_inpatient_beds_7_day_sum:422', 'ccn:070008', 'city:STAFFORD SPRINGS', 'collection_week:2020/07/31',
#    'collection_week:2020/08/07', 'collection_week:2020/08/14', 'collection_week:2020/08/21', 'collection_week:2020/08/28',
#    'collection_week:2020/09/04', 'collection_week:2020/09/11', 'collection_week:2020/09/18', 'collection_week:2020/09/25',
#    'collection_week:2020/10/02', 'collection_week:2020/10/09', 'collection_week:2020/10/16', 'collection_week:2020/10/23',
#    'collection_week:2020/10/30', 'collection_week:2020/11/06', 'collection_week:2020/11/13', 'collection_week:2020/11/20',
#    'collection_week:2020/11/27', 'collection_week:2020/12/04', 'collection_week:2020/12/11', 'collection_week:2020/12/18',
#    'collection_week:2020/12/25', 'collection_week:2021/01/01', 'collection_week:2021/01/08', 'collection_week:2021/01/15',
#    'collection_week:2021/01/22', 'collection_week:2021/01/29', 'collection_week:2021/02/05', 'collection_week:2021/02/12',
#    'collection_week:2021/02/19', 'collection_week:2021/02/26', 'collection_week:2021/03/05', 'collection_week:2021/03/12',
#    'collection_week:2021/03/19', 'collection_week:2021/03/26', 'collection_week:2021/04/02', 'collection_week:2021/04/09',
#    'collection_week:2021/04/16', 'collection_week:2021/04/23', 'collection_week:2021/04/30', 'collection_week:2021/05/07',
#    'collection_week:2021/05/14', 'collection_week:2021/05/21', 'collection_week:2021/05/28', 'collection_week:2021/06/04',
#    'collection_week:2021/06/11', 'collection_week:2021/06/18', 'collection_week:2021/06/25', 'collection_week:2021/07/02',
#    'collection_week:2021/07/09', 'collection_week:2021/07/16', 'collection_week:2021/07/23', 'collection_week:2021/07/30',
#    'collection_week:2021/08/06', 'collection_week:2021/08/13', 'collection_week:2021/08/20', 'collection_week:2021/08/27',
#    'collection_week:2021/09/03', 'collection_week:2021/09/10', 'collection_week:2021/09/17', 'collection_week:2021/09/24',
#    'collection_week:2021/10/01', 'collection_week:2021/10/08', 'collection_week:2021/10/15', 'collection_week:2021/10/22',
#    'collection_week:2021/10/29', 'collection_week:2021/11/05', 'collection_week:2021/11/12', 'collection_week:2021/11/19',
#    'collection_week:2021/11/26', 'collection_week:2021/12/03', 'collection_week:2021/12/10', 'collection_week:2021/12/17',
#    'collection_week:2021/12/24', 'collection_week:2021/12/31', 'collection_week:2022/01/07', 'collection_week:2022/01/14',
#    'collection_week:2022/01/21', 'collection_week:2022/01/28', 'collection_week:2022/02/04', 'collection_week:2022/02/11',
#    'collection_week:2022/02/18', 'collection_week:2022/02/25', 'collection_week:2022/03/04', 'fips_code:09013', 'geocoded_hospital_address:',
#    'hhs_ids:[C070008-A]', 'hospital_name:JOHNSON MEMORIAL HOSPITAL', 'hospital_pk:070008', 'hospital_subtype:Short Term',
#    'icu_beds_used_7_day_avg:-999999', 'icu_beds_used_7_day_avg:4', 'icu_beds_used_7_day_avg:4.1', 'icu_beds_used_7_day_avg:4.3',
#    'icu_beds_used_7_day_avg:4.4', 'icu_beds_used_7_day_avg:4.6', 'icu_beds_used_7_day_avg:4.7', 'icu_beds_used_7_day_avg:4.9',
#    'icu_beds_used_7_day_avg:5', 'icu_beds_used_7_day_avg:5.1', 'icu_beds_used_7_day_avg:5.6', 'icu_beds_used_7_day_avg:5.7',
#    'icu_beds_used_7_day_avg:5.9', 'icu_beds_used_7_day_coverage:6', 'icu_beds_used_7_day_coverage:7', 'icu_beds_used_7_day_sum:10',
#    'icu_beds_used_7_day_sum:11', 'icu_beds_used_7_day_sum:12', 'icu_beds_used_7_day_sum:13', 'icu_beds_used_7_day_sum:15',
#    'icu_beds_used_7_day_sum:16', 'icu_beds_used_7_day_sum:17', 'icu_beds_used_7_day_sum:18', 'icu_beds_used_7_day_sum:19',
#    'icu_beds_used_7_day_sum:20', 'icu_beds_used_7_day_sum:21', 'icu_beds_used_7_day_sum:22', 'icu_beds_used_7_day_sum:23',
#    'icu_beds_used_7_day_sum:24', 'icu_beds_used_7_day_sum:25', 'icu_beds_used_7_day_sum:26', 'icu_beds_used_7_day_sum:27',
#    'icu_beds_used_7_day_sum:28', 'icu_beds_used_7_day_sum:29', 'icu_beds_used_7_day_sum:30', 'icu_beds_used_7_day_sum:31',
#    'icu_beds_used_7_day_sum:32', 'icu_beds_used_7_day_sum:33', 'icu_beds_used_7_day_sum:34', 'icu_beds_used_7_day_sum:35',
#    'icu_beds_used_7_day_sum:36', 'icu_beds_used_7_day_sum:39', 'icu_beds_used_7_day_sum:40', 'icu_beds_used_7_day_sum:41',
#    'icu_beds_used_7_day_sum:9', 'icu_patients_confirmed_influenza_7_day_avg:', 'icu_patients_confirmed_influenza_7_day_avg:0',
#    'icu_patients_confirmed_influenza_7_day_coverage:0', 'icu_patients_confirmed_influenza_7_day_coverage:7',
#    'icu_patients_confirmed_influenza_7_day_sum:', 'icu_patients_confirmed_influenza_7_day_sum:0', 'inpatient_beds_7_day_avg:47.9',
#    'inpatient_beds_7_day_avg:48.1', 'inpatient_beds_7_day_avg:49.3', 'inpatient_beds_7_day_avg:50.1', 'inpatient_beds_7_day_avg:52',
#    'inpatient_beds_7_day_avg:55', 'inpatient_beds_7_day_avg:60.3', 'inpatient_beds_7_day_coverage:6', 'inpatient_beds_7_day_coverage:7',
#    'inpatient_beds_7_day_sum:330', 'inpatient_beds_7_day_sum:335', 'inpatient_beds_7_day_sum:337', 'inpatient_beds_7_day_sum:345',
#    'inpatient_beds_7_day_sum:351', 'inpatient_beds_7_day_sum:364', 'inpatient_beds_7_day_sum:385', 'inpatient_beds_7_day_sum:422',
#    'inpatient_beds_used_7_day_avg:23.4', 'inpatient_beds_used_7_day_avg:23.9', 'inpatient_beds_used_7_day_avg:24',
#    'inpatient_beds_used_7_day_avg:25.1', 'inpatient_beds_used_7_day_avg:25.9', 'inpatient_beds_used_7_day_avg:26',
#    'inpatient_beds_used_7_day_avg:26.4', 'inpatient_beds_used_7_day_avg:27', 'inpatient_beds_used_7_day_avg:27.3',
#    'inpatient_beds_used_7_day_avg:27.6', 'inpatient_beds_used_7_day_avg:28', 'inpatient_beds_used_7_day_avg:28.6',
#    'inpatient_beds_used_7_day_avg:28.7', 'inpatient_beds_used_7_day_avg:29', 'inpatient_beds_used_7_day_avg:29.1',
#    'inpatient_beds_used_7_day_avg:29.3', 'inpatient_beds_used_7_day_avg:29.4', 'inpatient_beds_used_7_day_avg:29.6',
#    'inpatient_beds_used_7_day_avg:29.7', 'inpatient_beds_used_7_day_avg:29.9', 'inpatient_beds_used_7_day_avg:30',
#    'inpatient_beds_used_7_day_avg:30.1', 'inpatient_beds_used_7_day_avg:30.3', 'inpatient_beds_used_7_day_avg:30.4',
#    'inpatient_beds_used_7_day_avg:30.6', 'inpatient_beds_used_7_day_avg:30.7', 'inpatient_beds_used_7_day_avg:31',
#    'inpatient_beds_used_7_day_avg:31.1', 'inpatient_beds_used_7_day_avg:31.3', 'inpatient_beds_used_7_day_avg:31.4',
#    'inpatient_beds_used_7_day_avg:31.6', 'inpatient_beds_used_7_day_avg:31.9', 'inpatient_beds_used_7_day_avg:32.1',
#    'inpatient_beds_used_7_day_avg:32.3', 'inpatient_beds_used_7_day_avg:32.4', 'inpatient_beds_used_7_day_avg:32.6',
#    'inpatient_beds_used_7_day_avg:32.7', 'inpatient_beds_used_7_day_avg:32.9', 'inpatient_beds_used_7_day_avg:33',
#    'inpatient_beds_used_7_day_avg:33.3', 'inpatient_beds_used_7_day_avg:33.4', 'inpatient_beds_used_7_day_avg:33.6',
#    'inpatient_beds_used_7_day_avg:34.1', 'inpatient_beds_used_7_day_avg:34.3', 'inpatient_beds_used_7_day_avg:34.4',
#    'inpatient_beds_used_7_day_avg:34.6', 'inpatient_beds_used_7_day_avg:34.7', 'inpatient_beds_used_7_day_avg:34.9',
#    'inpatient_beds_used_7_day_avg:35', 'inpatient_beds_used_7_day_avg:35.3', 'inpatient_beds_used_7_day_avg:35.4',
#    'inpatient_beds_used_7_day_avg:35.9', 'inpatient_beds_used_7_day_avg:36.1', 'inpatient_beds_used_7_day_avg:36.3',
#    'inpatient_beds_used_7_day_avg:36.7', 'inpatient_beds_used_7_day_avg:37', 'inpatient_beds_used_7_day_avg:37.9', 'inpatient_beds_used_7_day_avg:38',
#    'inpatient_beds_used_7_day_avg:39.7', 'inpatient_beds_used_7_day_coverage:6', 'inpatient_beds_used_7_day_coverage:7',
#    'inpatient_beds_used_7_day_sum:164', 'inpatient_beds_used_7_day_sum:167', 'inpatient_beds_used_7_day_sum:168', 'inpatient_beds_used_7_day_sum:176',
#    'inpatient_beds_used_7_day_sum:181', 'inpatient_beds_used_7_day_sum:182', 'inpatient_beds_used_7_day_sum:185', 'inpatient_beds_used_7_day_sum:189',
#    'inpatient_beds_used_7_day_sum:191', 'inpatient_beds_used_7_day_sum:193', 'inpatient_beds_used_7_day_sum:196', 'inpatient_beds_used_7_day_sum:200',
#    'inpatient_beds_used_7_day_sum:201', 'inpatient_beds_used_7_day_sum:203', 'inpatient_beds_used_7_day_sum:204', 'inpatient_beds_used_7_day_sum:205',
#    'inpatient_beds_used_7_day_sum:206', 'inpatient_beds_used_7_day_sum:207', 'inpatient_beds_used_7_day_sum:208', 'inpatient_beds_used_7_day_sum:209',
#    'inpatient_beds_used_7_day_sum:210', 'inpatient_beds_used_7_day_sum:211', 'inpatient_beds_used_7_day_sum:213', 'inpatient_beds_used_7_day_sum:214',
#    'inpatient_beds_used_7_day_sum:215', 'inpatient_beds_used_7_day_sum:217', 'inpatient_beds_used_7_day_sum:218', 'inpatient_beds_used_7_day_sum:219',
#    'inpatient_beds_used_7_day_sum:220', 'inpatient_beds_used_7_day_sum:221', 'inpatient_beds_used_7_day_sum:223', 'inpatient_beds_used_7_day_sum:225',
#    'inpatient_beds_used_7_day_sum:226', 'inpatient_beds_used_7_day_sum:227', 'inpatient_beds_used_7_day_sum:228', 'inpatient_beds_used_7_day_sum:229',
#    'inpatient_beds_used_7_day_sum:230', 'inpatient_beds_used_7_day_sum:231', 'inpatient_beds_used_7_day_sum:233', 'inpatient_beds_used_7_day_sum:234',
#    'inpatient_beds_used_7_day_sum:235', 'inpatient_beds_used_7_day_sum:239', 'inpatient_beds_used_7_day_sum:240', 'inpatient_beds_used_7_day_sum:241',
#    'inpatient_beds_used_7_day_sum:242', 'inpatient_beds_used_7_day_sum:243', 'inpatient_beds_used_7_day_sum:244', 'inpatient_beds_used_7_day_sum:245',
#    'inpatient_beds_used_7_day_sum:247', 'inpatient_beds_used_7_day_sum:248', 'inpatient_beds_used_7_day_sum:251', 'inpatient_beds_used_7_day_sum:253',
#    'inpatient_beds_used_7_day_sum:254', 'inpatient_beds_used_7_day_sum:257', 'inpatient_beds_used_7_day_sum:259', 'inpatient_beds_used_7_day_sum:265',
#    'inpatient_beds_used_7_day_sum:266', 'inpatient_beds_used_7_day_sum:278', 'inpatient_beds_used_covid_7_day_avg:-999999',
#    'inpatient_beds_used_covid_7_day_avg:0', 'inpatient_beds_used_covid_7_day_avg:10', 'inpatient_beds_used_covid_7_day_avg:11.4',
#    'inpatient_beds_used_covid_7_day_avg:12.6', 'inpatient_beds_used_covid_7_day_avg:4.3', 'inpatient_beds_used_covid_7_day_avg:4.4',
#    'inpatient_beds_used_covid_7_day_avg:4.6', 'inpatient_beds_used_covid_7_day_avg:5.3', 'inpatient_beds_used_covid_7_day_avg:5.9',
#    'inpatient_beds_used_covid_7_day_avg:6.3', 'inpatient_beds_used_covid_7_day_avg:6.6', 'inpatient_beds_used_covid_7_day_avg:6.7',
#    'inpatient_beds_used_covid_7_day_avg:7.1', 'inpatient_beds_used_covid_7_day_avg:7.6', 'inpatient_beds_used_covid_7_day_avg:7.9',
#    'inpatient_beds_used_covid_7_day_avg:9.4', 'inpatient_beds_used_covid_7_day_avg:9.7', 'inpatient_beds_used_covid_7_day_coverage:7',
#    'inpatient_beds_used_covid_7_day_sum:-999999', 'inpatient_beds_used_covid_7_day_sum:0', 'inpatient_beds_used_covid_7_day_sum:10',
#    'inpatient_beds_used_covid_7_day_sum:12', 'inpatient_beds_used_covid_7_day_sum:13', 'inpatient_beds_used_covid_7_day_sum:14',
#    'inpatient_beds_used_covid_7_day_sum:15', 'inpatient_beds_used_covid_7_day_sum:16', 'inpatient_beds_used_covid_7_day_sum:17',
#    'inpatient_beds_used_covid_7_day_sum:18', 'inpatient_beds_used_covid_7_day_sum:19', 'inpatient_beds_used_covid_7_day_sum:20',
#    'inpatient_beds_used_covid_7_day_sum:21', 'inpatient_beds_used_covid_7_day_sum:22', 'inpatient_beds_used_covid_7_day_sum:23',
#    'inpatient_beds_used_covid_7_day_sum:25', 'inpatient_beds_used_covid_7_day_sum:26', 'inpatient_beds_used_covid_7_day_sum:27',
#    'inpatient_beds_used_covid_7_day_sum:30', 'inpatient_beds_used_covid_7_day_sum:31', 'inpatient_beds_used_covid_7_day_sum:32',
#    'inpatient_beds_used_covid_7_day_sum:37', 'inpatient_beds_used_covid_7_day_sum:4', 'inpatient_beds_used_covid_7_day_sum:41',
#    'inpatient_beds_used_covid_7_day_sum:44', 'inpatient_beds_used_covid_7_day_sum:46', 'inpatient_beds_used_covid_7_day_sum:47',
#    'inpatient_beds_used_covid_7_day_sum:5', 'inpatient_beds_used_covid_7_day_sum:50', 'inpatient_beds_used_covid_7_day_sum:53',
#    'inpatient_beds_used_covid_7_day_sum:55', 'inpatient_beds_used_covid_7_day_sum:6', 'inpatient_beds_used_covid_7_day_sum:66',
#    'inpatient_beds_used_covid_7_day_sum:68', 'inpatient_beds_used_covid_7_day_sum:7', 'inpatient_beds_used_covid_7_day_sum:70',
#    'inpatient_beds_used_covid_7_day_sum:8', 'inpatient_beds_used_covid_7_day_sum:80', 'inpatient_beds_used_covid_7_day_sum:88',
#    'inpatient_beds_used_covid_7_day_sum:9', 'is_corrected:false', 'is_corrected:true', 'is_metro_micro:true',
#    'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:4', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:5',
#    'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:6', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:4',
#    'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:5', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:6',
#    'previous_day_admission_adult_covid_confirmed_7_day_coverage:7', 'previous_day_admission_adult_covid_confirmed_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_sum:10',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:11', 'previous_day_admission_adult_covid_confirmed_7_day_sum:13',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:14', 'previous_day_admission_adult_covid_confirmed_7_day_sum:16',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:17', 'previous_day_admission_adult_covid_confirmed_7_day_sum:4',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:5', 'previous_day_admission_adult_covid_confirmed_7_day_sum:6',
#    'previous_day_admission_adult_covid_confirmed_7_day_sum:7', 'previous_day_admission_adult_covid_confirmed_7_day_sum:9',
#    'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:-999999', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0',
#    'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:4', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:5',
#    'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:6', 'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0',
#    'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:57', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_70-79_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_7_day_coverage:6',
#    'previous_day_admission_adult_covid_suspected_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_7_day_sum:10',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:11', 'previous_day_admission_adult_covid_suspected_7_day_sum:12',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:13', 'previous_day_admission_adult_covid_suspected_7_day_sum:15',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:16', 'previous_day_admission_adult_covid_suspected_7_day_sum:4',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:5', 'previous_day_admission_adult_covid_suspected_7_day_sum:57',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:8',
#    'previous_day_admission_adult_covid_suspected_7_day_sum:9', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:-999999',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:10',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:11', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:12',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:13', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:15',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:16', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:4',
#    'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:7', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:9',
#    'previous_day_admission_influenza_confirmed_7_day_sum:', 'previous_day_admission_influenza_confirmed_7_day_sum:-999999',
#    'previous_day_admission_influenza_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:6',
#    'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:7', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0',
#    'previous_day_admission_pediatric_covid_suspected_7_day_coverage:3', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:5',
#    'previous_day_admission_pediatric_covid_suspected_7_day_coverage:6', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7',
#    'previous_day_admission_pediatric_covid_suspected_7_day_sum:-999999', 'previous_day_admission_pediatric_covid_suspected_7_day_sum:0',
#    'previous_day_covid_ED_visits_7_day_sum:10', 'previous_day_covid_ED_visits_7_day_sum:101', 'previous_day_covid_ED_visits_7_day_sum:102',
#    'previous_day_covid_ED_visits_7_day_sum:107', 'previous_day_covid_ED_visits_7_day_sum:108', 'previous_day_covid_ED_visits_7_day_sum:110',
#    'previous_day_covid_ED_visits_7_day_sum:111', 'previous_day_covid_ED_visits_7_day_sum:118', 'previous_day_covid_ED_visits_7_day_sum:12',
#    'previous_day_covid_ED_visits_7_day_sum:120', 'previous_day_covid_ED_visits_7_day_sum:142', 'previous_day_covid_ED_visits_7_day_sum:149',
#    'previous_day_covid_ED_visits_7_day_sum:152', 'previous_day_covid_ED_visits_7_day_sum:17', 'previous_day_covid_ED_visits_7_day_sum:18',
#    'previous_day_covid_ED_visits_7_day_sum:184', 'previous_day_covid_ED_visits_7_day_sum:22', 'previous_day_covid_ED_visits_7_day_sum:24',
#    'previous_day_covid_ED_visits_7_day_sum:25', 'previous_day_covid_ED_visits_7_day_sum:27', 'previous_day_covid_ED_visits_7_day_sum:272',
#    'previous_day_covid_ED_visits_7_day_sum:28', 'previous_day_covid_ED_visits_7_day_sum:29', 'previous_day_covid_ED_visits_7_day_sum:30',
#    'previous_day_covid_ED_visits_7_day_sum:32', 'previous_day_covid_ED_visits_7_day_sum:37', 'previous_day_covid_ED_visits_7_day_sum:39',
#    'previous_day_covid_ED_visits_7_day_sum:41', 'previous_day_covid_ED_visits_7_day_sum:45', 'previous_day_covid_ED_visits_7_day_sum:46',
#    'previous_day_covid_ED_visits_7_day_sum:48', 'previous_day_covid_ED_visits_7_day_sum:52', 'previous_day_covid_ED_visits_7_day_sum:53',
#    'previous_day_covid_ED_visits_7_day_sum:54', 'previous_day_covid_ED_visits_7_day_sum:55', 'previous_day_covid_ED_visits_7_day_sum:56',
#    'previous_day_covid_ED_visits_7_day_sum:57', 'previous_day_covid_ED_visits_7_day_sum:59', 'previous_day_covid_ED_visits_7_day_sum:61',
#    'previous_day_covid_ED_visits_7_day_sum:64', 'previous_day_covid_ED_visits_7_day_sum:66', 'previous_day_covid_ED_visits_7_day_sum:69',
#    'previous_day_covid_ED_visits_7_day_sum:70', 'previous_day_covid_ED_visits_7_day_sum:72', 'previous_day_covid_ED_visits_7_day_sum:73',
#    'previous_day_covid_ED_visits_7_day_sum:78', 'previous_day_covid_ED_visits_7_day_sum:82', 'previous_day_covid_ED_visits_7_day_sum:84',
#    'previous_day_covid_ED_visits_7_day_sum:85', 'previous_day_covid_ED_visits_7_day_sum:87', 'previous_day_covid_ED_visits_7_day_sum:90',
#    'previous_day_covid_ED_visits_7_day_sum:95', 'previous_day_covid_ED_visits_7_day_sum:96', 'previous_day_covid_ED_visits_7_day_sum:99',
#    'previous_day_total_ED_visits_7_day_sum:241', 'previous_day_total_ED_visits_7_day_sum:248', 'previous_day_total_ED_visits_7_day_sum:250',
#    'previous_day_total_ED_visits_7_day_sum:267', 'previous_day_total_ED_visits_7_day_sum:269', 'previous_day_total_ED_visits_7_day_sum:272',
#    'previous_day_total_ED_visits_7_day_sum:273', 'previous_day_total_ED_visits_7_day_sum:277', 'previous_day_total_ED_visits_7_day_sum:280',
#    'previous_day_total_ED_visits_7_day_sum:282', 'previous_day_total_ED_visits_7_day_sum:283', 'previous_day_total_ED_visits_7_day_sum:284',
#    'previous_day_total_ED_visits_7_day_sum:285', 'previous_day_total_ED_visits_7_day_sum:290', 'previous_day_total_ED_visits_7_day_sum:293',
#    'previous_day_total_ED_visits_7_day_sum:296', 'previous_day_total_ED_visits_7_day_sum:297', 'previous_day_total_ED_visits_7_day_sum:298',
#    'previous_day_total_ED_visits_7_day_sum:302', 'previous_day_total_ED_visits_7_day_sum:305', 'previous_day_total_ED_visits_7_day_sum:308',
#    'previous_day_total_ED_visits_7_day_sum:310', 'previous_day_total_ED_visits_7_day_sum:313', 'previous_day_total_ED_visits_7_day_sum:315',
#    'previous_day_total_ED_visits_7_day_sum:317', 'previous_day_total_ED_visits_7_day_sum:319', 'previous_day_total_ED_visits_7_day_sum:321',
#    'previous_day_total_ED_visits_7_day_sum:322', 'previous_day_total_ED_visits_7_day_sum:323', 'previous_day_total_ED_visits_7_day_sum:324',
#    'previous_day_total_ED_visits_7_day_sum:325', 'previous_day_total_ED_visits_7_day_sum:326', 'previous_day_total_ED_visits_7_day_sum:328',
#    'previous_day_total_ED_visits_7_day_sum:335', 'previous_day_total_ED_visits_7_day_sum:336', 'previous_day_total_ED_visits_7_day_sum:338',
#    'previous_day_total_ED_visits_7_day_sum:339', 'previous_day_total_ED_visits_7_day_sum:340', 'previous_day_total_ED_visits_7_day_sum:342',
#    'previous_day_total_ED_visits_7_day_sum:343', 'previous_day_total_ED_visits_7_day_sum:344', 'previous_day_total_ED_visits_7_day_sum:345',
#    'previous_day_total_ED_visits_7_day_sum:349', 'previous_day_total_ED_visits_7_day_sum:350', 'previous_day_total_ED_visits_7_day_sum:354',
#    'previous_day_total_ED_visits_7_day_sum:357', 'previous_day_total_ED_visits_7_day_sum:359', 'previous_day_total_ED_visits_7_day_sum:362',
#    'previous_day_total_ED_visits_7_day_sum:365', 'previous_day_total_ED_visits_7_day_sum:368', 'previous_day_total_ED_visits_7_day_sum:373',
#    'previous_day_total_ED_visits_7_day_sum:377', 'previous_day_total_ED_visits_7_day_sum:380', 'previous_day_total_ED_visits_7_day_sum:381',
#    'previous_day_total_ED_visits_7_day_sum:384', 'previous_day_total_ED_visits_7_day_sum:388', 'previous_day_total_ED_visits_7_day_sum:400',
#    'previous_day_total_ED_visits_7_day_sum:401', 'previous_day_total_ED_visits_7_day_sum:402', 'previous_day_total_ED_visits_7_day_sum:404',
#    'previous_day_total_ED_visits_7_day_sum:408', 'previous_day_total_ED_visits_7_day_sum:412', 'previous_day_total_ED_visits_7_day_sum:414',
#    'previous_day_total_ED_visits_7_day_sum:419', 'previous_day_total_ED_visits_7_day_sum:425', 'previous_day_total_ED_visits_7_day_sum:437',
#    'previous_day_total_ED_visits_7_day_sum:465', 'previous_day_total_ED_visits_7_day_sum:488', 'previous_day_total_ED_visits_7_day_sum:564',
#    'previous_week_patients_covid_vaccinated_doses_all_7_day:', 'previous_week_patients_covid_vaccinated_doses_one_7_day:',
#    'previous_week_personnel_covid_vaccinated_doses_administered_7_day:', 'staffed_adult_icu_bed_occupancy_7_day_avg:-999999',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:4', 'staffed_adult_icu_bed_occupancy_7_day_avg:4.1', 'staffed_adult_icu_bed_occupancy_7_day_avg:4.3',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:4.4', 'staffed_adult_icu_bed_occupancy_7_day_avg:4.6', 'staffed_adult_icu_bed_occupancy_7_day_avg:4.7',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:4.9', 'staffed_adult_icu_bed_occupancy_7_day_avg:5', 'staffed_adult_icu_bed_occupancy_7_day_avg:5.1',
#    'staffed_adult_icu_bed_occupancy_7_day_avg:5.6', 'staffed_adult_icu_bed_occupancy_7_day_avg:5.7', 'staffed_adult_icu_bed_occupancy_7_day_avg:5.9',
#    'staffed_adult_icu_bed_occupancy_7_day_coverage:6', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:10', 'staffed_adult_icu_bed_occupancy_7_day_sum:11', 'staffed_adult_icu_bed_occupancy_7_day_sum:12',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:13', 'staffed_adult_icu_bed_occupancy_7_day_sum:15', 'staffed_adult_icu_bed_occupancy_7_day_sum:16',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:17', 'staffed_adult_icu_bed_occupancy_7_day_sum:18', 'staffed_adult_icu_bed_occupancy_7_day_sum:19',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:20', 'staffed_adult_icu_bed_occupancy_7_day_sum:21', 'staffed_adult_icu_bed_occupancy_7_day_sum:22',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:23', 'staffed_adult_icu_bed_occupancy_7_day_sum:24', 'staffed_adult_icu_bed_occupancy_7_day_sum:25',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:26', 'staffed_adult_icu_bed_occupancy_7_day_sum:27', 'staffed_adult_icu_bed_occupancy_7_day_sum:28',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:29', 'staffed_adult_icu_bed_occupancy_7_day_sum:30', 'staffed_adult_icu_bed_occupancy_7_day_sum:31',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:32', 'staffed_adult_icu_bed_occupancy_7_day_sum:33', 'staffed_adult_icu_bed_occupancy_7_day_sum:34',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:35', 'staffed_adult_icu_bed_occupancy_7_day_sum:36', 'staffed_adult_icu_bed_occupancy_7_day_sum:39',
#    'staffed_adult_icu_bed_occupancy_7_day_sum:40', 'staffed_adult_icu_bed_occupancy_7_day_sum:41', 'staffed_adult_icu_bed_occupancy_7_day_sum:9',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:0', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:4.3',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:6',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:-999999',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:10',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:11', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:12',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:13', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:14',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:15', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:16',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:17', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:18',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:21', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:22',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:23', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:30',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:4', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:5',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:6', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:7',
#    'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:8', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:9',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_avg:-999999', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.3', 'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:6',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:-999999',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:10',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:11', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:12',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:15', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:16',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:17', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:18',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:21', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:22',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:23', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:30',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:4', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:5',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:6', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:7',
#    'staffed_icu_adult_patients_confirmed_covid_7_day_sum:8', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:9', 'state:CT',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:10',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:11.4',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:12.6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:4.3',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:4.4',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:4.6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:5.3',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:5.9',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:6.3',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:6.6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:6.7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:7.1',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:7.6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:7.9',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:9.4',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:9.7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:-999999',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:10',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:12',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:13',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:14',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:15',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:16',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:17',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:18',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:19',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:20',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:21',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:22',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:23',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:25',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:26',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:27',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:30',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:31',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:32',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:37',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:4',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:41',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:44',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:46',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:47',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:5',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:50',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:53',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:55',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:6',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:66',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:68',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:7',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:70',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:8',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:80',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:88',
#    'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:9',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:-999999', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:0',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:10', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:11.3',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:11.9', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:4.4',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:4.6', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:4.7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:4.9', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:5.3',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:6', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:6.7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:7.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:7.9',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:9', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:9.3',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:6', 'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:-999999', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:0',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:11',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:12', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:13',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:14', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:15',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:16', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:17',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:18', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:19',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:20', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:23',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:27',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:31', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:32',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:33', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:34',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:37', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:4',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:42', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:47',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:5', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:51',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:55', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:6',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:63', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:65',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:70',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:79', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:8',
# ...
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:8.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:8.4',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:87.7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:9.1',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:97.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:101',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:103', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:111',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:112', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:113',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:116', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:13',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:133', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:14',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:142', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:15',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:151', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:17',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:184', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:19',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:195', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:197',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:203', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:215',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:22', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:220',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:23', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:232',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:240', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:248',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:254',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:258', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:266',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:278', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:28',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:293', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:30',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:306', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:313',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:315', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:32',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:321', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:327',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:33', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:353',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:37', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:40',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:409', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:418',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:42', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:44',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:46', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:47',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:48', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:52',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:53', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:54',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:58', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:59',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:614', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:64',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:681', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:70',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:71', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:73',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:75', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:85',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:86', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:90',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:92', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:95',
#    'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:96', 'total_beds_7_day_avg:1039.4', 'total_beds_7_day_avg:1045.9',
#    'total_beds_7_day_avg:1051.7', 'total_beds_7_day_avg:1063.9', 'total_beds_7_day_avg:1079.9', 'total_beds_7_day_avg:1082.3',
#    'total_beds_7_day_avg:1089.4', 'total_beds_7_day_avg:1110.6', 'total_beds_7_day_avg:1120', 'total_beds_7_day_avg:1121',
#    'total_beds_7_day_avg:1125.3', 'total_beds_7_day_avg:1128.1', 'total_beds_7_day_avg:1157', 'total_beds_7_day_avg:1187.7',
#    'total_beds_7_day_avg:1192', 'total_beds_7_day_avg:1212.4', 'total_beds_7_day_avg:1244', 'total_beds_7_day_avg:1244.3',
#    'total_beds_7_day_avg:1244.7', 'total_beds_7_day_avg:1246.6', 'total_beds_7_day_avg:401.4', 'total_beds_7_day_avg:483.3',
#    'total_beds_7_day_avg:515.1', 'total_beds_7_day_avg:534.9', 'total_beds_7_day_avg:540.4', 'total_beds_7_day_avg:543', 'total_beds_7_day_avg:544.7',
#    'total_beds_7_day_avg:571.3', 'total_beds_7_day_avg:573.3', 'total_beds_7_day_avg:580.7', 'total_beds_7_day_avg:582', 'total_beds_7_day_avg:588.3',
#    'total_beds_7_day_avg:593.6', 'total_beds_7_day_avg:594.7', 'total_beds_7_day_avg:607.7', 'total_beds_7_day_avg:610.7',
#    'total_beds_7_day_avg:612.3', 'total_beds_7_day_avg:619', 'total_beds_7_day_avg:625', 'total_beds_7_day_avg:625.7', 'total_beds_7_day_avg:625.9',
#    'total_beds_7_day_avg:627.1', 'total_beds_7_day_avg:627.3', 'total_beds_7_day_avg:628.4', 'total_beds_7_day_avg:629', 'total_beds_7_day_avg:629.1',
#    'total_beds_7_day_avg:630.3', 'total_beds_7_day_avg:630.4', 'total_beds_7_day_avg:630.6', 'total_beds_7_day_avg:630.7',
#    'total_beds_7_day_avg:631.3', 'total_beds_7_day_avg:631.6', 'total_beds_7_day_avg:631.7', 'total_beds_7_day_avg:632', 'total_beds_7_day_avg:632.4',
#    'total_beds_7_day_avg:632.7', 'total_beds_7_day_avg:632.9', 'total_beds_7_day_avg:633.1', 'total_beds_7_day_avg:633.3',
#    'total_beds_7_day_avg:633.7', 'total_beds_7_day_avg:634', 'total_beds_7_day_avg:635.3', 'total_beds_7_day_avg:636.1', 'total_beds_7_day_avg:637',
#    'total_beds_7_day_avg:637.4', 'total_beds_7_day_avg:637.9', 'total_beds_7_day_avg:638.4', 'total_beds_7_day_avg:639.6',
#    'total_beds_7_day_avg:640.3', 'total_beds_7_day_avg:642', 'total_beds_7_day_avg:645', 'total_beds_7_day_avg:665.1', 'total_beds_7_day_avg:721',
#    'total_beds_7_day_avg:738.1', 'total_beds_7_day_avg:739.1', 'total_beds_7_day_avg:739.6', 'total_beds_7_day_coverage:7',
#    'total_beds_7_day_sum:2810', 'total_beds_7_day_sum:3383', 'total_beds_7_day_sum:3606', 'total_beds_7_day_sum:3744', 'total_beds_7_day_sum:3783',
#    'total_beds_7_day_sum:3801', 'total_beds_7_day_sum:3813', 'total_beds_7_day_sum:3999', 'total_beds_7_day_sum:4013', 'total_beds_7_day_sum:4065',
#    'total_beds_7_day_sum:4074', 'total_beds_7_day_sum:4118', 'total_beds_7_day_sum:4155', 'total_beds_7_day_sum:4163', 'total_beds_7_day_sum:4254',
#    'total_beds_7_day_sum:4275', 'total_beds_7_day_sum:4286', 'total_beds_7_day_sum:4333', 'total_beds_7_day_sum:4375', 'total_beds_7_day_sum:4380',
#    'total_beds_7_day_sum:4381', 'total_beds_7_day_sum:4390', 'total_beds_7_day_sum:4391', 'total_beds_7_day_sum:4399', 'total_beds_7_day_sum:4403',
#    'total_beds_7_day_sum:4404', 'total_beds_7_day_sum:4412', 'total_beds_7_day_sum:4413', 'total_beds_7_day_sum:4414', 'total_beds_7_day_sum:4415',
#    'total_beds_7_day_sum:4419', 'total_beds_7_day_sum:4421', 'total_beds_7_day_sum:4422', 'total_beds_7_day_sum:4424', 'total_beds_7_day_sum:4427',
#    'total_beds_7_day_sum:4429', 'total_beds_7_day_sum:4430', 'total_beds_7_day_sum:4432', 'total_beds_7_day_sum:4433', 'total_beds_7_day_sum:4436',
#    'total_beds_7_day_sum:4438', 'total_beds_7_day_sum:4447', 'total_beds_7_day_sum:4453', 'total_beds_7_day_sum:4459', 'total_beds_7_day_sum:4462',
#    'total_beds_7_day_sum:4465', 'total_beds_7_day_sum:4469', 'total_beds_7_day_sum:4477', 'total_beds_7_day_sum:4482', 'total_beds_7_day_sum:4494',
#    'total_beds_7_day_sum:4515', 'total_beds_7_day_sum:4656', 'total_beds_7_day_sum:5047', 'total_beds_7_day_sum:5167', 'total_beds_7_day_sum:5174',
#    'total_beds_7_day_sum:5177', 'total_beds_7_day_sum:7276', 'total_beds_7_day_sum:7321', 'total_beds_7_day_sum:7362', 'total_beds_7_day_sum:7447',
#    'total_beds_7_day_sum:7559', 'total_beds_7_day_sum:7576', 'total_beds_7_day_sum:7626', 'total_beds_7_day_sum:7774', 'total_beds_7_day_sum:7840',
#    'total_beds_7_day_sum:7847', 'total_beds_7_day_sum:7877', 'total_beds_7_day_sum:7897', 'total_beds_7_day_sum:8099', 'total_beds_7_day_sum:8314',
#    'total_beds_7_day_sum:8344', 'total_beds_7_day_sum:8487', 'total_beds_7_day_sum:8708', 'total_beds_7_day_sum:8710', 'total_beds_7_day_sum:8713',
#    'total_beds_7_day_sum:8726', 'total_icu_beds_7_day_avg:27.9', 'total_icu_beds_7_day_avg:28', 'total_icu_beds_7_day_avg:28.3',
#    'total_icu_beds_7_day_avg:28.6', 'total_icu_beds_7_day_avg:28.7', 'total_icu_beds_7_day_avg:28.9', 'total_icu_beds_7_day_avg:29.1',
#    'total_icu_beds_7_day_avg:30.9', 'total_icu_beds_7_day_avg:33.1', 'total_icu_beds_7_day_avg:38', 'total_icu_beds_7_day_avg:38.3',
#    'total_icu_beds_7_day_avg:38.6', 'total_icu_beds_7_day_avg:38.7', 'total_icu_beds_7_day_avg:38.9', 'total_icu_beds_7_day_avg:39',
#    'total_icu_beds_7_day_avg:39.1', 'total_icu_beds_7_day_avg:39.3', 'total_icu_beds_7_day_avg:39.6', 'total_icu_beds_7_day_avg:39.7',
#    'total_icu_beds_7_day_avg:40', 'total_icu_beds_7_day_avg:40.1', 'total_icu_beds_7_day_avg:40.4', 'total_icu_beds_7_day_avg:40.6',
#    'total_icu_beds_7_day_avg:40.9', 'total_icu_beds_7_day_avg:41', 'total_icu_beds_7_day_avg:41.1', 'total_icu_beds_7_day_avg:41.4',
#    'total_icu_beds_7_day_avg:41.7', 'total_icu_beds_7_day_avg:42', 'total_icu_beds_7_day_avg:42.4', 'total_icu_beds_7_day_avg:43.1',
#    'total_icu_beds_7_day_avg:45', 'total_icu_beds_7_day_avg:45.4', 'total_icu_beds_7_day_avg:48', 'total_icu_beds_7_day_avg:48.4',
#    'total_icu_beds_7_day_avg:53', 'total_icu_beds_7_day_coverage:7', 'total_icu_beds_7_day_sum:195', 'total_icu_beds_7_day_sum:196',
#    'total_icu_beds_7_day_sum:198', 'total_icu_beds_7_day_sum:200', 'total_icu_beds_7_day_sum:201', 'total_icu_beds_7_day_sum:202',
#    'total_icu_beds_7_day_sum:204', 'total_icu_beds_7_day_sum:216', 'total_icu_beds_7_day_sum:232', 'total_icu_beds_7_day_sum:266',
#    'total_icu_beds_7_day_sum:268', 'total_icu_beds_7_day_sum:270', 'total_icu_beds_7_day_sum:271', 'total_icu_beds_7_day_sum:272',
#    'total_icu_beds_7_day_sum:273', 'total_icu_beds_7_day_sum:274', 'total_icu_beds_7_day_sum:275', 'total_icu_beds_7_day_sum:277',
#    'total_icu_beds_7_day_sum:278', 'total_icu_beds_7_day_sum:280', 'total_icu_beds_7_day_sum:281', 'total_icu_beds_7_day_sum:283',
#    'total_icu_beds_7_day_sum:284', 'total_icu_beds_7_day_sum:286', 'total_icu_beds_7_day_sum:287', 'total_icu_beds_7_day_sum:288',
#    'total_icu_beds_7_day_sum:290', 'total_icu_beds_7_day_sum:292', 'total_icu_beds_7_day_sum:294', 'total_icu_beds_7_day_sum:297',
#    'total_icu_beds_7_day_sum:302', 'total_icu_beds_7_day_sum:315', 'total_icu_beds_7_day_sum:318', 'total_icu_beds_7_day_sum:336',
#    'total_icu_beds_7_day_sum:339', 'total_icu_beds_7_day_sum:371', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:',
#    'total_patients_hospitalized_confirmed_influenza_7_day_avg:0', 'total_patients_hospitalized_confirmed_influenza_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_7_day_coverage:5', 'total_patients_hospitalized_confirmed_influenza_7_day_coverage:7',
#    'total_patients_hospitalized_confirmed_influenza_7_day_sum:', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:5',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:6',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:7',
#    'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:-999999',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:10.3',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:-999999',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:6',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:7',
#    'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:72',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:-999999', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:-999999', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:26', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:6',
#    'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:7', 'total_personnel_covid_vaccinated_doses_all_7_day:',
#    'total_personnel_covid_vaccinated_doses_none_7_day:', 'total_personnel_covid_vaccinated_doses_one_7_day:',
#    'total_staffed_adult_icu_beds_7_day_avg:19.7', 'total_staffed_adult_icu_beds_7_day_avg:23', 'total_staffed_adult_icu_beds_7_day_avg:23.9',
#    'total_staffed_adult_icu_beds_7_day_avg:25.6', 'total_staffed_adult_icu_beds_7_day_avg:26.1', 'total_staffed_adult_icu_beds_7_day_avg:26.6',
#    'total_staffed_adult_icu_beds_7_day_avg:27.9', 'total_staffed_adult_icu_beds_7_day_avg:28', 'total_staffed_adult_icu_beds_7_day_avg:28.7',
#    'total_staffed_adult_icu_beds_7_day_avg:31.3', 'total_staffed_adult_icu_beds_7_day_avg:33', 'total_staffed_adult_icu_beds_7_day_coverage:7',
#    'total_staffed_adult_icu_beds_7_day_sum:138', 'total_staffed_adult_icu_beds_7_day_sum:161', 'total_staffed_adult_icu_beds_7_day_sum:167',
#    'total_staffed_adult_icu_beds_7_day_sum:179', 'total_staffed_adult_icu_beds_7_day_sum:183', 'total_staffed_adult_icu_beds_7_day_sum:186',
#    'total_staffed_adult_icu_beds_7_day_sum:195', 'total_staffed_adult_icu_beds_7_day_sum:196', 'total_staffed_adult_icu_beds_7_day_sum:201',
#    'total_staffed_adult_icu_beds_7_day_sum:219', 'total_staffed_adult_icu_beds_7_day_sum:231', 'zip:11432'})]
# End_____Task A_____Test_____Data_____

# %% [markdown]
# ## B. Minhash: Create a “signature” for each hospital
# - Use the efficient Minhashing approach to convert the set representation of each hospital into 100 dimensions by using hashes on the set strings.

# %% [markdown]
# **Checkpoint B:**
# We store the hash functions in a broadcast variable. This setup allows for the configuration of a process where a `reduceByKey`, utilizing sid as the key, is implemented. The purpose of this configuration is to efficiently identify the minimum hashed value corresponding to each 'feat' for every 'sid'.

# %%
import math
import random
import pprint

def hash_fun(rdd):
    hospital_id, signature = rdd[0], rdd[1]
    min_hash_value = math.inf
    min_hash_results, hash_functions = [], []

    hash_functions = [(random.randint(1, 99), random.randint(1, 99)) for _ in range(0, 100)]
    min_hash_results = [min([((data * hash_element) + seed) % (10**6) for hash_element in signature]) for data, seed in hash_functions]

    return min_hash_results

def process_data(data):
    printer = pprint.PrettyPrinter(width=90, compact=True)
    processed_data_rdd = data.mapPartitions(lambda y: map(lambda x: (x[0], hash_fun(x)), y))

    checkpoint_data = ['150034', '050739', '330231', '241326', '070008']
    requested_data = processed_data_rdd.filter(lambda x: x[0] in checkpoint_data)
    printer.pprint(requested_data.collect())

    return processed_data_rdd

print('Start_____Custom Task_____Trail Data:')
custom_set_signatures_trail = process_data(hospital_data_trial)
print('End_____Custom Task_____Trail Data')
custom_set_signatures_trail
print('Start_____Custom Task_____Test Data:')
custom_set_signatures_test = process_data(hospital_data_test)
print('End_____Custom Task_____Test Data')
custom_set_signatures_test
# Out:
# Start_____Task B_____Trail Data:
# [('150034',
#   [184932, 218288, 109046, 60922, 150707, 685705, 45397, 92860, 60878, 19497, 132209,
#    61882, 87964, 481933, 38445, 45807, 319960, 191585, 132233, 61869, 110256, 196337,
#    90812, 29412, 28815, 218304, 68102, 3691, 38402, 79488, 147455, 65747, 191594, 191628,
#    128181, 68131, 61948, 34078, 4051, 369832, 24728, 90849, 191643, 190007, 30479, 130147,
#    56767, 184996, 3661, 169297, 60936, 147444, 61872, 481908, 19533, 241677, 34111,
#    140692, 45773, 110195, 469321, 19231, 102132, 337927, 272940, 34115, 469365, 319956,
#    102112, 98208, 45395, 108314, 70372, 347350, 21036, 61888, 19215, 130136, 4036, 130128,
#    90808, 68161, 178412, 30437, 90828, 46409, 3631, 218353, 151260, 166164, 65677, 130144,
#    196293, 95997, 56817, 34043, 29398, 135270, 300682, 150692]),
#  ('050739',
#   [67285, 56799, 300683, 4019, 135265, 178449, 102114, 77426, 79400, 61878, 57615, 50511,
#    300655, 38463, 137821, 128199, 347335, 79417, 30997, 30969, 109106, 108306, 19538,
#    150723, 266035, 76842, 392531, 34081, 61945, 132178, 57658, 48023, 65069, 89217, 87968,
#    96076, 298881, 300684, 9649, 298812, 67226, 61912, 248734, 169036, 60887, 392587,
#    166192, 15526, 92853, 90760, 151249, 337835, 247606, 128349, 178479, 68102, 695105,
#    60203, 255061, 31028, 128345, 137842, 188929, 695095, 10884, 237356, 337908, 143548,
#    264391, 110194, 21051, 166176, 196271, 151274, 109124, 76871, 247644, 143565, 89254,
#    237429, 149491, 255020, 69730, 15506, 119007, 695188, 69820, 89287, 98224, 337978,
#    108295, 392600, 70326, 90245, 168992, 50568, 109088, 61962, 140664, 100780]),
#  ('330231',
#   [147421, 109103, 584496, 298835, 89245, 60934, 255023, 109085, 218310, 92859, 640896,
#    127559, 177703, 65111, 193186, 584493, 395394, 385004, 51457, 197779, 270488, 325278,
#    46470, 67264, 21045, 190014, 4022, 385006, 89246, 135220, 43338, 298861, 237402,
#    574740, 319917, 99538, 237367, 177693, 99539, 67198, 409430, 395431, 92810, 108320,
#    57642, 308916, 19450, 178406, 325275, 178407, 60917, 166231, 574707, 178422, 21060,
#    137807, 92805, 31025, 128372, 118633, 166168, 105683, 325223, 181667, 155667, 227612,
#    43402, 407914, 128405, 105677, 135225, 100755, 135228, 45821, 157022, 255016, 208622,
#    100766, 61889, 141555, 70369, 212994, 30996, 88825, 325210, 168947, 147460, 140699,
#    51505, 15512, 208574, 130152, 237404, 355334, 1276, 237237, 109101, 321683, 137789,
#    181656]),
#  ('150034',
#   [157012, 19256, 19296, 19475, 15513, 308977, 316929, 24746, 128333, 24763, 77378,
#    300680, 177649, 77417, 316960, 147438, 469313, 88887, 38425, 300655, 214588, 135230,
#    11628, 337926, 30996, 640887, 147445, 266009, 584548, 76800, 169011, 46454, 695180,
#    28850, 474316, 151252, 181663, 4041, 77367, 584527, 355334, 385027, 191599, 60959,
#    476403, 104297, 51421, 96021, 87998, 384985, 24765, 476397, 347386, 30974, 321763,
#    107261, 323644, 128195, 189964, 300680, 191605, 118624, 51456, 1821, 370801, 76839,
#    385021, 227617, 168954, 24691, 70370, 44010, 177721, 22937, 193134, 38459, 156981,
#    265985, 178393, 208610, 181666, 108290, 30976, 337969, 43992, 385002, 316927, 397726,
#    178436, 193195, 304378, 150746, 65092, 1826, 28885, 60907, 28847, 51481, 88016,
#    574740]),
#  ('241326',
#   [70311, 67224, 100814, 455164, 30771, 323602, 124462, 105653, 89422, 38414, 218338,
#    238427, 124535, 319968, 86471, 265964, 621701, 89446, 455112, 184553, 300625, 39914,
#    167593, 29390, 239339, 169362, 119695, 43998, 239333, 193404, 281171, 347358, 319887,
#    377809, 215321, 110258, 65154, 621762, 169039, 155275, 1854, 183163, 92283, 65080,
#    128270, 65650, 48015, 169332, 109091, 28871, 562310, 215310, 22920, 193422, 118673,
#    19236, 455194, 67196, 562287, 621720, 130123, 155250, 621764, 89285, 118596, 277801,
#    167611, 323611, 236655, 215312, 1816, 19216, 11558, 434989, 140667, 215333, 272995,
#    92296, 178482, 86449, 310504, 155275, 323572, 300672, 60880, 100281, 96004, 29318,
#    51471, 310511, 171058, 277737, 90829, 183117, 60896, 309239, 39971, 319893, 277801,
#    61583]),
#  ('070008',
#   [1817, 325273, 30466, 562249, 21042, 19216, 215349, 89227, 57659, 105633, 137789,
#    152389, 121603, 118651, 208658, 71441, 109048, 96006, 152355, 109106, 24764, 178462,
#    395456, 227573, 89243, 337946, 395381, 283105, 70322, 38402, 355324, 562244, 237246,
#    197771, 92841, 60934, 89253, 19280, 108345, 43377, 128363, 128237, 135232, 30838,
#    208641, 227584, 57652, 60926, 153845, 152411, 65140, 181682, 215340, 92855, 46429,
#    43398, 562257, 99543, 255065, 237234, 60935, 57355, 237194, 104362, 3699, 67201, 1820,
#    92286, 325262, 469280, 248974, 135313, 19449, 20988, 319945, 215384, 128213, 58712,
#    46481, 3634, 60904, 45794, 130184, 197747, 104361, 355281, 71427, 237228, 323605, 4054,
#    385007, 28853, 65060, 215369, 67277, 227602, 197733, 19260, 47996, 29328])]
# End_____Task B_____Trail Data
# Start_____Task B_____Test Data:
# [Stage 43:======================================>                 (22 + 8) / 32]
# [('150034',
#   [151272, 157033, 319973, 151215, 64000, 1886, 140692, 60873, 157033, 19264, 265957,
#    70376, 77372, 11596, 319915, 3611, 191602, 236650, 19475, 208574, 30967, 214622,
#    266039, 481964, 189995, 171013, 88882, 208574, 92842, 189985, 56738, 70356, 4036,
#    218292, 319907, 31017, 236656, 150759, 227573, 76862, 191605, 67289, 272993, 102155,
#    214654, 185009, 407859, 88019, 65655, 149484, 151221, 108315, 147411, 4036, 76875,
#    67223, 110213, 241704, 32896, 188961, 407856, 48028, 407857, 685749, 96010, 337971,
#    191590, 469315, 481911, 19250, 100754, 157003, 347378, 30990, 79435, 337937, 48019,
#    132165, 407848, 3994, 140629, 32922, 56766, 168959, 19280, 227618, 108316, 46456,
#    407839, 29433, 241724, 32886, 60952, 188933, 151281, 92799, 143518, 19521, 96086,
#    128257]),
#  ('050739',
#   [96003, 208647, 87953, 104325, 275624, 67239, 89253, 61912, 11433, 110243, 298793,
#    61903, 34093, 695141, 140623, 38472, 90264, 92862, 77337, 300645, 446015, 10915, 30510,
#    96011, 22932, 178461, 69743, 90761, 108292, 4066, 89248, 20477, 76852, 445929, 48069,
#    45397, 188897, 196266, 90223, 150757, 166225, 188966, 45800, 102184, 264371, 143552,
#    109037, 137818, 22897, 132174, 130180, 337903, 45396, 1838, 132198, 89273, 60900,
#    264369, 19209, 50511, 69791, 158704, 95993, 50583, 22944, 56765, 77393, 19472, 130174,
#    21033, 255024, 92852, 48041, 90801, 22900, 207958, 166196, 337918, 92855, 149442,
#    143537, 270480, 3996, 77374, 45401, 10846, 11354, 157019, 156978, 695148, 3603, 300602,
#    168966, 188966, 208002, 169566, 149398, 137858, 22958, 98216]),
#  ('330231',
#   [19502, 88858, 48051, 469335, 11574, 57685, 584515, 323594, 157055, 118660, 355302,
#    140624, 212935, 640942, 24699, 1250, 38447, 395445, 110212, 61946, 353360, 255015,
#    407835, 168970, 67243, 409401, 218327, 100735, 1823, 88887, 237399, 395416, 61919,
#    640943, 9628, 640951, 15487, 308938, 469287, 337899, 48063, 237213, 384978, 469366,
#    237216, 193159, 104375, 30463, 60941, 166206, 355343, 88013, 128195, 28820, 395385,
#    181639, 4061, 189965, 323558, 30476, 193150, 96022, 22957, 212945, 65065, 149445,
#    395366, 283115, 110251, 96075, 104349, 20992, 96088, 469332, 141563, 157019, 181620,
#    208634, 105642, 197730, 474377, 308919, 19290, 281952, 384968, 319901, 191581, 237189,
#    197753, 51454, 85466, 323570, 141605, 88897, 218338, 281960, 24748, 353329, 28825,
#    156998]),
#  ('150034',
#   [77369, 149470, 308895, 70349, 46492, 87996, 89255, 109111, 254990, 151275, 118600,
#    584487, 77414, 319903, 377787, 266021, 19493, 147398, 181628, 70361, 337972, 15504,
#    11566, 147376, 469313, 48086, 328404, 237425, 323580, 4038, 51446, 347396, 1883,
#    218293, 385022, 110242, 316932, 31028, 555506, 266038, 300652, 61947, 397731, 118578,
#    77366, 135230, 109047, 177687, 48006, 227610, 28815, 275609, 77340, 9614, 135304,
#    574785, 316943, 166197, 640900, 300613, 178454, 178431, 67260, 1881, 178471, 48055,
#    584505, 104363, 181695, 51430, 151253, 397725, 321757, 137873, 584513, 70377, 149490,
#    128329, 38399, 255054, 128362, 67290, 169013, 397752, 476414, 3613, 135265, 77373,
#    193128, 214532, 44027, 157050, 92881, 110230, 308962, 28868, 11580, 407866, 128328,
#    177641]),
#  ('241326',
#   [89418, 193416, 100252, 19249, 88009, 1852, 21001, 169026, 88013, 277777, 187426, 27931,
#    45807, 300630, 100212, 70349, 184560, 3614, 239333, 27923, 110274, 90905, 187446,
#    30807, 19242, 110271, 178434, 216279, 455139, 178432, 238373, 272947, 92283, 621711,
#    151240, 272939, 44060, 184606, 237235, 60888, 309183, 169348, 151236, 187460, 29412,
#    110275, 239281, 60956, 434978, 167617, 147459, 92316, 455188, 167628, 294826, 281137,
#    22973, 93733, 337951, 128275, 27925, 237195, 65663, 562292, 183131, 21014, 38456,
#    119631, 90871, 119651, 205023, 105636, 152390, 128341, 278240, 128262, 238421, 136514,
#    215348, 109050, 151253, 310475, 277779, 1837, 167643, 128190, 24740, 323604, 60887,
#    407918, 19278, 277782, 377841, 319936, 130189, 3690, 227589, 140609, 151210, 32837]),
#  ('070008',
#   [93760, 187508, 21012, 496456, 405640, 65083, 496480, 337941, 124541, 61548, 227635,
#    92275, 28804, 30452, 70315, 183141, 45859, 1842, 177710, 110249, 155667, 30794, 496494,
#    29382, 153828, 3662, 89400, 88887, 562248, 57443, 395417, 237172, 70371, 137794,
#    248989, 43325, 215320, 147463, 110225, 21081, 183132, 218270, 283126, 181652, 70336,
#    3658, 395448, 4074, 9680, 58670, 384991, 29338, 9640, 100752, 57404, 128256, 281180,
#    46404, 152379, 128346, 325221, 124553, 562239, 124469, 9614, 124502, 319885, 51463,
#    147425, 21061, 3616, 123046, 43402, 58644, 128327, 57377, 237216, 218266, 128326,
#    395373, 147424, 184538, 3694, 19276, 319902, 21077, 128379, 325251, 135283, 208647,
#    140611, 169032, 60948, 105676, 178424, 30449, 152365, 405607, 58704, 319941])]
# End_____Task B_____Test Data
# PythonRDD[73] at RDD at PythonRDD.scala:53

# %% [markdown]
# ## C. Find similar pairs using LSH
# - Run LSH to find approximately 20 candidates.

# %% [markdown]
# **Checkpoint C:**
# We should employ Locality-Sensitive Hashing (LSH) to identify roughly 20 hospitals that exhibit similarities to our specified hospitals: 150034, 50739, 330231, 241326, and 70008. Within the LSH framework, each hospital is conceptualized as a column, with each row signifying a signature matrix value. To arrive at approximately 20 candidate hospitals, it's necessary to fine-tune the number of bands and rows per band in our approach.

# %%
import random

similarity_dict = {}

def calculate_jaccard_similarity(sig_x, sig_y):
    set_x, set_y = set(sig_x), set(sig_y)
    str_set_x, str_set_y = str(set_x), str(set_y)

    key = tuple(sorted([str_set_x, str_set_y]))

    if key in similarity_dict:
        return similarity_dict[key]
    else:
        res_jsim = len(set_x.intersection(set_y)) / len(set_x.union(set_y))
        similarity_dict[key] = res_jsim
        return res_jsim

def LSH(sig):
    hospital_pk, signature = sig[0], sig[1]
    buckets = []

    for itms in range(int(len(signature) / 8)):
        opti, y = itms, itms * 8
        elements = ' '.join(str(nsg) for nsg in signature[y:y+8])
        buckets.append(((opti, ((random.randint(1, 100) * hash(elements)) + random.randint(1, 100)) % (10**6)), hospital_pk))

    return iter(buckets)

def print_task_output(signature_set, candidates):
    checkpoint_c_list = ['150034', '050739', '330231', '241326', '070008']

    selected_candidates = candidates.filter(lambda x: x[0] in checkpoint_c_list).collect()
    selected_signatures = signature_set.filter(lambda x: x[0] in checkpoint_c_list).collect()

    for i in range(5):
        print('Hospital_pk:', checkpoint_c_list[i])
        nums = 1
        candidate_hospitals = selected_candidates[i][1]
        candidate_signatures = signature_set.filter(lambda x: x[0] in candidate_hospitals and x[0] != checkpoint_c_list[i]).collect()

        for j in candidate_signatures:
            if nums <= 20:
                print(f'\t{nums} Hospital_pk:', j[0])
                print(f'\tsimilarity:', calculate_jaccard_similarity(selected_signatures[i][1], j[1]))
                print(f'\tsignature matrix:', j[1][0:10], '\n')
                nums += 1

length = hospital_data_trial.count()
trail_hosp_coll = set_signatures_trail.flatMap(LSH).groupByKey()
trail_coll_hosp_data = trail_hosp_coll.mapPartitions(lambda y: map(lambda x: (x[0], list(x[1])), y))
trail_candidates = trail_coll_hosp_data.flatMap(lambda x: [(item, x[1]) for item in x[1]]).reduceByKey(lambda a, b: list(set(a + b)))

print('Trial C')
print_task_output(set_signatures_trail, trail_candidates)
print()

length = hospital_data_trial.count()
test_hosp_coll = set_signatures_test.flatMap(LSH).groupByKey()
test_coll_hosp_data = test_hosp_coll.mapPartitions(lambda y: map(lambda x: (x[0], list(x[1])), y))
test_candidates = test_coll_hosp_data.flatMap(lambda x: [(item, x[1]) for item in x[1]]).reduceByKey(lambda a, b: list(set(a + b)))

print('Test C')
print_task_output(set_signatures_test, test_candidates)
# Out:
# Trial C
# Hospital_pk:  150034
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [497059, 74743, 64837, 65873, 39780, 263497, 164493, 32958, 30063, 18848]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.005050505050505051
# 	signature matrix:  [71887, 4031, 118635, 397799, 22887, 10570, 321755, 30952, 254997, 181715]
#
# 	3 Hospital_pk:  050739
# 	similarity:  0.0
# 	signature matrix:  [65138, 15548, 247612, 65133, 39738, 90205, 337774, 11434, 19207, 69726]
#
# 	4 Hospital_pk:  330194
# 	similarity:  0.0
# 	signature matrix:  [518034, 130124, 61934, 150696, 57666, 518059, 227597, 77365, 227638, 22941]
#
# 	5 Hospital_pk:  521357
# 	similarity:  0.005076142131979695
# 	signature matrix:  [323589, 166178, 70331, 92854, 191591, 1866, 355365, 19274, 355357, 87999]
#
# 	6 Hospital_pk:  100051
# 	similarity:  0.005025125628140704
# 	signature matrix:  [270521, 347379, 130134, 193190, 96002, 247688, 10915, 191633, 237164, 140642]
#
# 	7 Hospital_pk:  271323
# 	similarity:  0.0
# 	signature matrix:  [88021, 110247, 77363, 19249, 135317, 166222, 298858, 128238, 214568, 178431]
#
# 	8 Hospital_pk:  020024
# 	similarity:  0.005050505050505051
# 	signature matrix:  [149444, 151225, 60953, 104345, 45801, 238440, 237237, 100241, 30979, 316975]
#
# 	9 Hospital_pk:  280132
# 	similarity:  0.0
# 	signature matrix:  [30460, 323626, 370799, 177675, 118637, 30854, 152339, 121665, 104333, 87998]
#
# 	10 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [96062, 105615, 105650, 107286, 355354, 95991, 108266, 109055, 319916, 189951]
#
# 	11 Hospital_pk:  451366
# 	similarity:  0.01015228426395939
# 	signature matrix:  [19289, 30990, 177647, 584503, 169014, 319916, 300604, 46471, 384979, 177710]
#
# 	12 Hospital_pk:  140103
# 	similarity:  0.01015228426395939
# 	signature matrix:  [214537, 227595, 105635, 108264, 22952, 24701, 110230, 214480, 328343, 9614]
#
# 	13 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [92865, 130128, 51473, 323554, 3697, 10869, 191567, 60138, 20527, 323619]
#
# 	14 Hospital_pk:  650003
# 	similarity:  0.0
# 	signature matrix:  [36038, 181663, 48041, 150740, 227694, 35986, 71909, 370823, 150759, 1853]
#
# 	15 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [88905, 137853, 4039, 76836, 239638, 77410, 167819, 23967, 130114, 469286]
#
# 	16 Hospital_pk:  050152
# 	similarity:  0.010101010101010102
# 	signature matrix:  [197703, 355348, 355301, 407858, 385020, 19517, 21009, 469311, 323563, 15476]
#
# 	17 Hospital_pk:  440009
# 	similarity:  0.0
# 	signature matrix:  [168988, 128404, 179204, 207952, 48076, 28798, 169511, 157027, 118622, 634659]
#
# 	18 Hospital_pk:  062017
# 	similarity:  0.0
# 	signature matrix:  [105655, 105605, 99451, 31026, 166186, 30945, 169025, 308904, 118649, 325246]
#
# 	19 Hospital_pk:  240018
# 	similarity:  0.005050505050505051
# 	signature matrix:  [60916, 61943, 118664, 45845, 48033, 3678, 92858, 218283, 24736, 137873]
#
# 	20 Hospital_pk:  420078
# 	similarity:  0.0
# 	signature matrix:  [196310, 4065, 19215, 188908, 108359, 34039, 218336, 21020, 46399, 29301]
#
# Hospital_pk:  050739
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [11784, 89594, 38634, 124746, 163422, 22044, 37648, 11372, 138718, 193096]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.005076142131979695
# 	signature matrix:  [51458, 87956, 270478, 15481, 147396, 51477, 140680, 67208, 316923, 193172]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [28827, 151238, 169349, 21081, 22718, 32880, 241692, 272982, 214600, 29440]
#
# 	4 Hospital_pk:  330194
# 	similarity:  0.0
# 	signature matrix:  [88903, 19206, 77351, 214641, 44068, 61871, 88913, 57597, 555475, 181638]
#
# 	5 Hospital_pk:  521357
# 	similarity:  0.0
# 	signature matrix:  [481967, 171068, 4037, 323595, 685765, 107276, 193193, 236655, 96031, 32879]
#
# 	6 Hospital_pk:  100051
# 	similarity:  0.005050505050505051
# 	signature matrix:  [109032, 321686, 270477, 270446, 87994, 60875, 270480, 43998, 15525, 270485]
#
# 	7 Hospital_pk:  271323
# 	similarity:  0.0
# 	signature matrix:  [189987, 695186, 4043, 208617, 46407, 57669, 130120, 397800, 3670, 377851]
#
# 	8 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [104315, 30155, 107241, 76795, 321687, 3646, 67253, 67224, 270457, 238440]
#
# 	9 Hospital_pk:  280132
# 	similarity:  0.005076142131979695
# 	signature matrix:  [27902, 15533, 107219, 130211, 130203, 24753, 266050, 237171, 57658, 128188]
#
# 	10 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [57356, 65674, 140610, 130160, 65681, 157039, 20994, 237211, 70361, 60885]
#
# 	11 Hospital_pk:  451366
# 	similarity:  0.0
# 	signature matrix:  [474386, 181639, 76801, 48076, 308936, 321702, 347332, 384970, 128252, 384955]
#
# 	12 Hospital_pk:  400125
# 	similarity:  0.005076142131979695
# 	signature matrix:  [685699, 3662, 685747, 128198, 279555, 89276, 39708, 237196, 61944, 236684]
#
# 	13 Hospital_pk:  140103
# 	similarity:  0.0
# 	signature matrix:  [87965, 46467, 3695, 574699, 227603, 214516, 308947, 135308, 77420, 214544]
#
# 	14 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [30454, 4022, 265969, 317328, 104374, 323620, 178468, 300623, 60914, 39724]
#
# 	15 Hospital_pk:  650003
# 	similarity:  0.005050505050505051
# 	signature matrix:  [237245, 328420, 695190, 151203, 218347, 193196, 19256, 270441, 128315, 695152]
#
# 	16 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [88821, 266029, 21061, 239641, 137791, 48007, 22942, 476476, 518063, 22955]
#
# 	17 Hospital_pk:  050152
# 	similarity:  0.005050505050505051
# 	signature matrix:  [29388, 57390, 89204, 43405, 168974, 197770, 1860, 337969, 237247, 51433]
#
# 	18 Hospital_pk:  440009
# 	similarity:  0.005050505050505051
# 	signature matrix:  [445927, 347328, 45796, 384940, 474360, 60136, 191597, 323620, 10897, 60900]
#
# 	19 Hospital_pk:  062017
# 	similarity:  0.0
# 	signature matrix:  [45823, 353320, 316915, 128348, 355336, 407911, 279569, 395434, 4046, 24709]
#
# 	20 Hospital_pk:  240018
# 	similarity:  0.0
# 	signature matrix:  [218339, 130173, 88822, 21030, 22615, 385017, 51513, 76828, 70389, 156987]
#
# Hospital_pk:  330231
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [107444, 11806, 21963, 209130, 48054, 43961, 48075, 19334, 38649, 163419]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.0
# 	signature matrix:  [140639, 4004, 140707, 15542, 137802, 1853, 300596, 77411, 46591, 12053]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [30459, 132201, 149421, 265960, 190009, 67219, 178482, 76842, 308954, 70331]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.005025125628140704
# 	signature matrix:  [65103, 39764, 46480, 128245, 95994, 19208, 158748, 264391, 4015, 151236]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.005025125628140704
# 	signature matrix:  [36022, 300620, 321730, 237222, 321755, 166209, 135317, 370821, 584514, 31019]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.005025125628140704
# 	signature matrix:  [140612, 46455, 177660, 19249, 130208, 118602, 65681, 574707, 100207, 272995]
#
# 	7 Hospital_pk:  100051
# 	similarity:  0.005025125628140704
# 	signature matrix:  [21057, 19532, 57600, 135285, 92832, 193180, 237210, 89257, 44002, 191601]
#
# 	8 Hospital_pk:  271323
# 	similarity:  0.010101010101010102
# 	signature matrix:  [193174, 92876, 265987, 270502, 70343, 218324, 218283, 166204, 265956, 65116]
#
# 	9 Hospital_pk:  020024
# 	similarity:  0.010101010101010102
# 	signature matrix:  [272996, 87982, 236676, 67216, 21072, 337923, 128267, 208603, 169600, 323583]
#
# 	10 Hospital_pk:  280132
# 	similarity:  0.005025125628140704
# 	signature matrix:  [100816, 109109, 93721, 19285, 337938, 70320, 107247, 60866, 218291, 85461]
#
# 	11 Hospital_pk:  050132
# 	similarity:  0.010101010101010102
# 	signature matrix:  [218317, 61911, 237161, 57393, 67198, 130142, 304394, 304388, 136478, 22910]
#
# 	12 Hospital_pk:  451366
# 	similarity:  0.0
# 	signature matrix:  [109043, 130122, 277739, 316971, 150780, 110190, 57605, 377781, 275619, 147415]
#
# 	13 Hospital_pk:  400125
# 	similarity:  0.005050505050505051
# 	signature matrix:  [20509, 65088, 89226, 130171, 279574, 685714, 168949, 44027, 128337, 9665]
#
# 	14 Hospital_pk:  140103
# 	similarity:  0.0
# 	signature matrix:  [92867, 137823, 128359, 298860, 128383, 149419, 149406, 1855, 19229, 128366]
#
# 	15 Hospital_pk:  421301
# 	similarity:  0.005025125628140704
# 	signature matrix:  [128400, 3639, 48070, 61897, 137871, 90256, 445999, 323598, 19508, 247620]
#
# 	16 Hospital_pk:  650003
# 	similarity:  0.005050505050505051
# 	signature matrix:  [150699, 167810, 407889, 254998, 83870, 96077, 218272, 88879, 67260, 214576]
#
# 	17 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [47956, 15501, 1883, 270535, 24005, 9609, 208612, 67289, 319904, 304377]
#
# 	18 Hospital_pk:  440009
# 	similarity:  0.005050505050505051
# 	signature matrix:  [20512, 89223, 140670, 110256, 50595, 149097, 193167, 15481, 384960, 255017]
#
# 	19 Hospital_pk:  062017
# 	similarity:  0.015306122448979591
# 	signature matrix:  [67281, 104345, 24740, 110218, 197724, 31020, 57653, 127566, 127555, 1309]
#
# 	20 Hospital_pk:  240018
# 	similarity:  0.0
# 	signature matrix:  [319906, 65116, 24720, 1889, 321690, 21056, 151205, 19447, 22561, 23981]
#
# Hospital_pk:  241326
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [43596, 54098, 79506, 54905, 164502, 54890, 128547, 120783, 191392, 163433]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.01020408163265306
# 	signature matrix:  [140662, 227686, 34623, 227574, 45785, 22900, 193182, 35942, 237160, 584523]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [64018, 57620, 130126, 140645, 143518, 120905, 19249, 108359, 128203, 61870]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.0
# 	signature matrix:  [96028, 108294, 39711, 69724, 1804, 39702, 110195, 22699, 110241, 109117]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.0
# 	signature matrix:  [208584, 304390, 140695, 24027, 35969, 179788, 11641, 38397, 555416, 300619]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.0
# 	signature matrix:  [4067, 177736, 77337, 168952, 70385, 685738, 32882, 135297, 57638, 30504]
#
# 	7 Hospital_pk:  100051
# 	similarity:  0.0
# 	signature matrix:  [128227, 275553, 107230, 298884, 108357, 39685, 89193, 15504, 193135, 191626]
#
# 	8 Hospital_pk:  271323
# 	similarity:  0.005076142131979695
# 	signature matrix:  [255054, 30522, 109086, 57690, 135297, 100798, 469310, 181715, 140707, 279595]
#
# 	9 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [105646, 237203, 247657, 20482, 150715, 96060, 272980, 39751, 15487, 266030]
#
# 	10 Hospital_pk:  280132
# 	similarity:  0.0
# 	signature matrix:  [184598, 237199, 151237, 92285, 147459, 300598, 108305, 269782, 24775, 121645]
#
# 	11 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [166228, 70380, 218314, 28833, 110269, 88864, 191656, 85422, 110221, 1260]
#
# 	12 Hospital_pk:  451366
# 	similarity:  0.015544041450777202
# 	signature matrix:  [76803, 89235, 57640, 277770, 89233, 109056, 147440, 147417, 275608, 189931]
#
# 	13 Hospital_pk:  400125
# 	similarity:  0.005050505050505051
# 	signature matrix:  [30518, 337822, 157016, 20987, 51487, 100241, 279545, 130161, 181649, 60923]
#
# 	14 Hospital_pk:  140103
# 	similarity:  0.005076142131979695
# 	signature matrix:  [208603, 640976, 96009, 218294, 319901, 574740, 135300, 193133, 476403, 77361]
#
# 	15 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [92814, 9646, 105674, 191601, 96001, 237182, 178422, 319916, 61919, 89267]
#
# 	16 Hospital_pk:  650003
# 	similarity:  0.01015228426395939
# 	signature matrix:  [92865, 59930, 214600, 70402, 319886, 60923, 128312, 21044, 4012, 22602]
#
# 	17 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [135241, 22909, 328401, 88893, 9684, 59947, 67277, 109038, 555469, 179720]
#
# 	18 Hospital_pk:  050152
# 	similarity:  0.0
# 	signature matrix:  [43403, 155681, 15474, 61571, 24722, 46427, 123043, 110225, 184599, 15496]
#
# 	19 Hospital_pk:  440009
# 	similarity:  0.005050505050505051
# 	signature matrix:  [237369, 30524, 321745, 321730, 207996, 128336, 347415, 30083, 15530, 247659]
#
# 	20 Hospital_pk:  062017
# 	similarity:  0.005076142131979695
# 	signature matrix:  [88901, 99526, 118598, 208577, 270440, 147441, 46441, 11555, 110266, 51436]
#
# Hospital_pk:  070008
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [134481, 28007, 43584, 65881, 128532, 142726, 21683, 95740, 12254, 12344]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.005050505050505051
# 	signature matrix:  [23970, 22620, 319924, 208579, 130117, 10591, 3633, 24036, 208590, 45829]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [128221, 169366, 191665, 79451, 110190, 4001, 61918, 45431, 167624, 98133]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.005025125628140704
# 	signature matrix:  [44015, 140609, 109079, 20472, 279583, 30126, 279523, 19484, 237432, 60908]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.005050505050505051
# 	signature matrix:  [181625, 11591, 193159, 275570, 92889, 227583, 19295, 11995, 4026, 214595]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.0
# 	signature matrix:  [193177, 43979, 151235, 63948, 65710, 140704, 77394, 11573, 51492, 140687]
#
# 	7 Hospital_pk:  100051
# 	similarity:  0.0
# 	signature matrix:  [137776, 22891, 104333, 104324, 24751, 1860, 695164, 337893, 317335, 347359]
#
# 	8 Hospital_pk:  271323
# 	similarity:  0.005050505050505051
# 	signature matrix:  [87980, 214518, 191576, 130194, 304388, 89278, 60951, 107252, 105626, 96060]
#
# 	9 Hospital_pk:  020024
# 	similarity:  0.010101010101010102
# 	signature matrix:  [21027, 247640, 89234, 22972, 208028, 149131, 272925, 108319, 89194, 38437]
#
# 	10 Hospital_pk:  280132
# 	similarity:  0.0
# 	signature matrix:  [355365, 3696, 60930, 30937, 65120, 51475, 168944, 370751, 208671, 87974]
#
# 	11 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [128253, 218346, 469321, 107306, 89195, 31016, 128382, 57645, 88024, 22939]
#
# 	12 Hospital_pk:  451366
# 	similarity:  0.010101010101010102
# 	signature matrix:  [43995, 128340, 135284, 147470, 108292, 275568, 474401, 304349, 65119, 48031]
#
# 	13 Hospital_pk:  400125
# 	similarity:  0.0
# 	signature matrix:  [10862, 107251, 208627, 270449, 45813, 57653, 270497, 48004, 70332, 236681]
#
# 	14 Hospital_pk:  140103
# 	similarity:  0.0
# 	signature matrix:  [31004, 70403, 21012, 385002, 308958, 105644, 308943, 70311, 169014, 21052]
#
# 	15 Hospital_pk:  421301
# 	similarity:  0.005050505050505051
# 	signature matrix:  [92864, 237188, 237241, 270469, 30115, 208648, 39693, 208597, 287299, 119078]
#
# 	16 Hospital_pk:  650003
# 	similarity:  0.005025125628140704
# 	signature matrix:  [57597, 1811, 67239, 270534, 92885, 347399, 328351, 319909, 76875, 270520]
#
# 	17 Hospital_pk:  050152
# 	similarity:  0.0
# 	signature matrix:  [9654, 135271, 89239, 407885, 60887, 96030, 67230, 19292, 92295, 323617]
#
# 	18 Hospital_pk:  440009
# 	similarity:  0.005025125628140704
# 	signature matrix:  [237237, 4066, 149125, 157060, 69773, 474370, 337886, 337802, 69817, 24730]
#
# 	19 Hospital_pk:  062017
# 	similarity:  0.01015228426395939
# 	signature matrix:  [31027, 99520, 140617, 156984, 48064, 384980, 147395, 24707, 99452, 15474]
#
# 	20 Hospital_pk:  240018
# 	similarity:  0.005050505050505051
# 	signature matrix:  [83892, 44025, 347374, 19227, 96065, 21010, 10633, 169003, 96065, 46403]
# Test C
# Hospital_pk:  150034
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [95744, 263480, 21715, 21988, 54060, 261432, 131805, 164732, 117254, 164495]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.0
# 	signature matrix:  [469296, 181692, 65093, 407873, 15469, 110204, 130182, 193177, 214653, 87970]
#
# 	3 Hospital_pk:  050739
# 	similarity:  0.005050505050505051
# 	signature matrix:  [319893, 22905, 56746, 96074, 178464, 109044, 24694, 9634, 56815, 92828]
#
# 	4 Hospital_pk:  330194
# 	similarity:  0.0
# 	signature matrix:  [347340, 60895, 22929, 407903, 28814, 208645, 270463, 147389, 67251, 214654]
#
# 	5 Hospital_pk:  521357
# 	similarity:  0.005050505050505051
# 	signature matrix:  [19223, 171059, 214634, 136529, 109046, 100283, 147393, 167621, 76808, 46450]
#
# 	6 Hospital_pk:  100051
# 	similarity:  0.005050505050505051
# 	signature matrix:  [128395, 110207, 87999, 19199, 30991, 347418, 48014, 48003, 128388, 4056]
#
# 	7 Hospital_pk:  271323
# 	similarity:  0.0
# 	signature matrix:  [88841, 67200, 150751, 57598, 237405, 574703, 397758, 128385, 65146, 277802]
#
# 	8 Hospital_pk:  020024
# 	similarity:  0.005050505050505051
# 	signature matrix:  [151214, 178471, 19481, 247645, 60158, 51432, 96031, 28882, 20544, 150739]
#
# 	9 Hospital_pk:  280132
# 	similarity:  0.0
# 	signature matrix:  [61598, 140630, 184578, 29369, 150694, 21080, 51430, 105602, 269723, 255009]
#
# 	10 Hospital_pk:  050132
# 	similarity:  0.005050505050505051
# 	signature matrix:  [141638, 353356, 130162, 128226, 89207, 407868, 11592, 105609, 99516, 24700]
#
# 	11 Hospital_pk:  451366
# 	similarity:  0.0
# 	signature matrix:  [130118, 298889, 4005, 321750, 214570, 300692, 28827, 304443, 178385, 279537]
#
# 	12 Hospital_pk:  400125
# 	similarity:  0.0
# 	signature matrix:  [135231, 79395, 287339, 70356, 140618, 30112, 3692, 135306, 51452, 270448]
#
# 	13 Hospital_pk:  140103
# 	similarity:  0.005076142131979695
# 	signature matrix:  [304399, 300656, 135232, 88919, 19538, 109041, 277794, 15529, 304376, 308959]
#
# 	14 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [1893, 67291, 67210, 92833, 11599, 30095, 279537, 60922, 337952, 46444]
#
# 	15 Hospital_pk:  650003
# 	similarity:  0.010256410256410256
# 	signature matrix:  [48038, 255021, 304403, 100773, 214655, 140632, 128349, 130187, 9696, 254991]
#
# 	16 Hospital_pk:  452042
# 	similarity:  0.005076142131979695
# 	signature matrix:  [584550, 157031, 191626, 237435, 45833, 179701, 44041, 157041, 65130, 469353]
#
# 	17 Hospital_pk:  050152
# 	similarity:  0.0
# 	signature matrix:  [89203, 385016, 395436, 469311, 22915, 140663, 88878, 21065, 123021, 152350]
#
# 	18 Hospital_pk:  240018
# 	similarity:  0.0
# 	signature matrix:  [19480, 239640, 61866, 83880, 83949, 265975, 300649, 253006, 34604, 46446]
#
# 	19 Hospital_pk:  420078
# 	similarity:  0.00510204081632653
# 	signature matrix:  [166194, 130138, 469313, 76841, 392589, 237413, 70338, 11366, 21054, 1263]
#
# 	20 Hospital_pk:  151327
# 	similarity:  0.01020408163265306
# 	signature matrix:  [149427, 67291, 157055, 189952, 190008, 96009, 44026, 45413, 67251, 143514]
#
# Hospital_pk:  050739
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [18243, 39764, 24058, 54969, 42073, 56598, 64807, 74743, 131767, 286188]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.0
# 	signature matrix:  [46495, 15547, 22644, 22596, 277754, 150730, 517972, 140707, 4009, 22571]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [369898, 135272, 96005, 191569, 88901, 30510, 191623, 167588, 135313, 65057]
#
# 	4 Hospital_pk:  330194
# 	similarity:  0.005050505050505051
# 	signature matrix:  [61918, 370753, 9629, 100791, 167785, 157061, 65082, 46434, 275585, 67231]
#
# 	5 Hospital_pk:  521357
# 	similarity:  0.01015228426395939
# 	signature matrix:  [337922, 149439, 135237, 685785, 96055, 147472, 227605, 316921, 76796, 469340]
#
# 	6 Hospital_pk:  271323
# 	similarity:  0.005076142131979695
# 	signature matrix:  [321719, 584478, 92828, 30450, 70332, 355287, 181638, 51452, 321767, 46455]
#
# 	7 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [446019, 179152, 218268, 128379, 150695, 337945, 9639, 109110, 22930, 29434]
#
# 	8 Hospital_pk:  280132
# 	similarity:  0.005076142131979695
# 	signature matrix:  [227596, 24704, 128265, 109061, 178395, 21052, 19526, 89260, 355282, 51483]
#
# 	9 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [337935, 236653, 43980, 51456, 88851, 110276, 337945, 3678, 105594, 141556]
#
# 	10 Hospital_pk:  451366
# 	similarity:  0.0
# 	signature matrix:  [640970, 65100, 150728, 51439, 46403, 208585, 277745, 130136, 308925, 156989]
#
# 	11 Hospital_pk:  400125
# 	similarity:  0.01015228426395939
# 	signature matrix:  [30978, 30083, 118619, 19515, 30073, 30467, 178424, 1823, 247678, 21076]
#
# 	12 Hospital_pk:  140103
# 	similarity:  0.01015228426395939
# 	signature matrix:  [46433, 304404, 156977, 30443, 255035, 149480, 237436, 105678, 38444, 108340]
#
# 	13 Hospital_pk:  421301
# 	similarity:  0.005050505050505051
# 	signature matrix:  [92856, 474322, 70348, 15549, 3997, 104340, 45844, 3682, 247599, 19222]
#
# 	14 Hospital_pk:  650003
# 	similarity:  0.0
# 	signature matrix:  [46550, 107314, 19541, 92864, 3679, 695149, 140687, 179764, 214659, 4065]
#
# 	15 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [300648, 193202, 119825, 87992, 107227, 239632, 265992, 22958, 11615, 67257]
#
# 	16 Hospital_pk:  050152
# 	similarity:  0.005076142131979695
# 	signature matrix:  [57663, 96082, 30482, 58681, 104314, 218303, 43341, 135268, 183118, 187421]
#
# 	17 Hospital_pk:  440009
# 	similarity:  0.005050505050505051
# 	signature matrix:  [474397, 270447, 118601, 337798, 45794, 28812, 109028, 149451, 107310, 10886]
#
# 	18 Hospital_pk:  062017
# 	similarity:  0.0
# 	signature matrix:  [304439, 181706, 325280, 384937, 135240, 118672, 110250, 319880, 19275, 319907]
#
# 	19 Hospital_pk:  240018
# 	similarity:  0.0
# 	signature matrix:  [227651, 304400, 12045, 48013, 24029, 59954, 19459, 71962, 130130, 59980]
#
# 	20 Hospital_pk:  420078
# 	similarity:  0.0
# 	signature matrix:  [147408, 213031, 92824, 110257, 4027, 70395, 196276, 88841, 166186, 147412]
#
# Hospital_pk:  330231
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [28045, 11456, 234542, 11055, 65920, 65924, 50171, 152477, 27987, 261396]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.0
# 	signature matrix:  [321709, 38453, 237199, 22564, 107270, 47988, 110208, 150729, 15511, 140665]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.01015228426395939
# 	signature matrix:  [44031, 196348, 270478, 128378, 61888, 481949, 135284, 147383, 1856, 481909]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.005025125628140704
# 	signature matrix:  [4036, 38495, 10907, 11352, 61953, 11563, 70371, 264350, 34063, 90173]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.00510204081632653
# 	signature matrix:  [3989, 128398, 252996, 10606, 218325, 584512, 181637, 60893, 128384, 167773]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.0
# 	signature matrix:  [104384, 24776, 177641, 469279, 92886, 128384, 88859, 214469, 107257, 67283]
#
# 	7 Hospital_pk:  100051
# 	similarity:  0.005076142131979695
# 	signature matrix:  [30967, 10876, 316930, 634650, 89285, 46478, 149466, 193143, 46494, 247624]
#
# 	8 Hospital_pk:  271323
# 	similarity:  0.02577319587628866
# 	signature matrix:  [476391, 298870, 214590, 370758, 48068, 279532, 476443, 87996, 108338, 181672]
#
# 	9 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [10881, 319966, 317327, 191576, 179113, 4054, 150772, 337847, 157031, 69774]
#
# 	10 Hospital_pk:  280132
# 	similarity:  0.005076142131979695
# 	signature matrix:  [128212, 60870, 27876, 208583, 51490, 248985, 61887, 27888, 187474, 496454]
#
# 	11 Hospital_pk:  050132
# 	similarity:  0.005076142131979695
# 	signature matrix:  [308969, 156985, 140669, 325262, 105671, 100794, 100739, 167630, 167637, 60880]
#
# 	12 Hospital_pk:  451366
# 	similarity:  0.01015228426395939
# 	signature matrix:  [323556, 11576, 47999, 157006, 177707, 266027, 275635, 44000, 377816, 355337]
#
# 	13 Hospital_pk:  400125
# 	similarity:  0.015544041450777202
# 	signature matrix:  [39760, 9617, 21028, 51508, 193175, 321690, 88016, 110242, 128327, 104311]
#
# 	14 Hospital_pk:  140103
# 	similarity:  0.005025125628140704
# 	signature matrix:  [370838, 61939, 105672, 227609, 640970, 218272, 70356, 19249, 377833, 695147]
#
# 	15 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [695143, 317406, 279596, 208005, 270512, 247690, 337977, 1876, 24752, 149452]
#
# 	16 Hospital_pk:  650003
# 	similarity:  0.0
# 	signature matrix:  [316906, 34549, 239618, 253046, 377772, 34529, 109036, 316922, 179760, 44044]
#
# 	17 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [22948, 316927, 104326, 135226, 193150, 316920, 110227, 167756, 76837, 384956]
#
# 	18 Hospital_pk:  050152
# 	similarity:  0.005025125628140704
# 	signature matrix:  [30798, 496435, 21038, 187452, 118608, 85450, 184581, 30468, 278328, 71475]
#
# 	19 Hospital_pk:  440009
# 	similarity:  0.005025125628140704
# 	signature matrix:  [130184, 193178, 45831, 24738, 60925, 108317, 255057, 130117, 60212, 105675]
#
# 	20 Hospital_pk:  062017
# 	similarity:  0.0
# 	signature matrix:  [92889, 308981, 355350, 109037, 140658, 141596, 323629, 270482, 48041, 85485]
#
# Hospital_pk:  241326
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [131768, 134506, 104733, 43964, 138750, 124774, 28059, 64826, 23550, 33009]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.01015228426395939
# 	signature matrix:  [237390, 67271, 10590, 65153, 316950, 218290, 227703, 83911, 3666, 104378]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.0
# 	signature matrix:  [104333, 407830, 308909, 147425, 149421, 685708, 24718, 169314, 265967, 218341]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.0
# 	signature matrix:  [76817, 149468, 43991, 22710, 151233, 61865, 30071, 266014, 11631, 98170]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.010256410256410256
# 	signature matrix:  [60864, 24770, 237425, 19444, 214572, 319975, 157069, 237162, 118617, 12045]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.01020408163265306
# 	signature matrix:  [130181, 265982, 181640, 150776, 151214, 208631, 19270, 237185, 238428, 15509]
#
# 	7 Hospital_pk:  100051
# 	similarity:  0.010101010101010102
# 	signature matrix:  [38440, 20472, 384975, 28837, 60959, 19515, 104335, 79344, 28852, 24781]
#
# 	8 Hospital_pk:  271323
# 	similarity:  0.005025125628140704
# 	signature matrix:  [385026, 584477, 347365, 370794, 328350, 11594, 248691, 107289, 19465, 181695]
#
# 	9 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [10903, 45802, 272906, 11592, 89210, 90239, 149055, 170996, 238442, 178477]
#
# 	10 Hospital_pk:  280132
# 	similarity:  0.0
# 	signature matrix:  [321691, 472414, 88013, 147419, 355305, 236279, 9687, 177659, 31000, 377843]
#
# 	11 Hospital_pk:  050132
# 	similarity:  0.0
# 	signature matrix:  [100827, 167582, 337966, 70361, 135250, 46472, 96012, 11559, 104349, 237208]
#
# 	12 Hospital_pk:  451366
# 	similarity:  0.0
# 	signature matrix:  [316981, 46489, 266032, 277708, 304361, 397707, 574707, 474397, 77346, 321695]
#
# 	13 Hospital_pk:  400125
# 	similarity:  0.0
# 	signature matrix:  [1850, 61925, 44068, 104355, 150725, 19287, 105625, 28859, 30969, 247684]
#
# 	14 Hospital_pk:  140103
# 	similarity:  0.0
# 	signature matrix:  [248724, 51512, 87959, 157004, 321739, 237363, 76848, 28815, 76832, 190010]
#
# 	15 Hospital_pk:  421301
# 	similarity:  0.0
# 	signature matrix:  [135233, 191581, 193139, 87982, 110247, 474391, 255042, 321733, 30975, 21035]
#
# 	16 Hospital_pk:  650003
# 	similarity:  0.02040816326530612
# 	signature matrix:  [48072, 38481, 46447, 150719, 10638, 4006, 137858, 38424, 328337, 45785]
#
# 	17 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [321738, 61963, 19479, 253081, 71923, 147388, 11573, 67218, 96060, 270504]
#
# 	18 Hospital_pk:  050152
# 	similarity:  0.005050505050505051
# 	signature matrix:  [405633, 407881, 30777, 58698, 70399, 87961, 155679, 177686, 71423, 177701]
#
# 	19 Hospital_pk:  440009
# 	similarity:  0.005025125628140704
# 	signature matrix:  [135240, 22975, 44024, 149068, 76882, 151206, 15520, 22972, 157000, 237428]
#
# 	20 Hospital_pk:  062017
# 	similarity:  0.0
# 	signature matrix:  [110198, 141640, 1279, 43979, 181650, 44048, 237221, 4042, 67265, 255008]
#
# Hospital_pk:  070008
# [Stage 63:========================================>               (23 + 8) / 32]
# 	1 Hospital_pk:  hospital_pk
# 	similarity:  0.0
# 	signature matrix:  [37624, 12513, 28005, 56019, 10701, 57976, 56442, 428801, 59276, 138772]
#
# 	2 Hospital_pk:  131312
# 	similarity:  0.0
# 	signature matrix:  [96027, 119864, 227622, 119884, 45833, 275560, 300667, 518066, 255038, 70332]
#
# 	3 Hospital_pk:  150034
# 	similarity:  0.005050505050505051
# 	signature matrix:  [136547, 32887, 9636, 28812, 196301, 337921, 128386, 3606, 65708, 88001]
#
# 	4 Hospital_pk:  050739
# 	similarity:  0.0
# 	signature matrix:  [30438, 265989, 30936, 188969, 196326, 69755, 109030, 110268, 34036, 149436]
#
# 	5 Hospital_pk:  330194
# 	similarity:  0.0
# 	signature matrix:  [270527, 59974, 214596, 214664, 22941, 88833, 23963, 71940, 48006, 518060]
#
# 	6 Hospital_pk:  521357
# 	similarity:  0.005025125628140704
# 	signature matrix:  [178421, 29419, 347350, 105622, 30526, 60918, 30947, 265969, 4069, 181656]
#
# 	7 Hospital_pk:  271323
# 	similarity:  0.005025125628140704
# 	signature matrix:  [237166, 60905, 377783, 60910, 109046, 323634, 300609, 191618, 208639, 150723]
#
# 	8 Hospital_pk:  020024
# 	similarity:  0.0
# 	signature matrix:  [77419, 109034, 19451, 247633, 321701, 105637, 70402, 191631, 208576, 100251]
#
# 	9 Hospital_pk:  280132
# 	similarity:  0.005025125628140704
# 	signature matrix:  [472407, 108330, 88001, 254979, 277755, 3990, 187493, 48684, 266004, 140693]
#
# 	10 Hospital_pk:  050132
# 	similarity:  0.005025125628140704
# 	signature matrix:  [147431, 141550, 63944, 337944, 281949, 270471, 395428, 157008, 178393, 11619]
#
# 	11 Hospital_pk:  451366
# 	similarity:  0.010101010101010102
# 	signature matrix:  [640965, 4071, 30982, 298870, 128356, 109054, 227617, 255029, 275602, 584476]
#
# 	12 Hospital_pk:  400125
# 	similarity:  0.005050505050505051
# 	signature matrix:  [445994, 168982, 50552, 57613, 65122, 151246, 92804, 140650, 61931, 207979]
#
# 	13 Hospital_pk:  140103
# 	similarity:  0.010101010101010102
# 	signature matrix:  [30933, 31004, 43998, 370835, 308909, 19268, 316928, 51456, 469371, 248707]
#
# 	14 Hospital_pk:  421301
# 	similarity:  0.005050505050505051
# 	signature matrix:  [321686, 151248, 46490, 77340, 128242, 169017, 79389, 79393, 44037, 3611]
#
# 	15 Hospital_pk:  650003
# 	similarity:  0.005050505050505051
# 	signature matrix:  [151269, 319941, 169016, 88827, 168987, 51495, 45847, 76847, 227639, 518039]
#
# 	16 Hospital_pk:  452042
# 	similarity:  0.0
# 	signature matrix:  [476448, 71944, 150726, 397710, 137832, 109118, 130171, 239610, 555421, 518018]
#
# 	17 Hospital_pk:  440009
# 	similarity:  0.0
# 	signature matrix:  [30099, 67196, 384992, 100803, 119052, 181630, 248716, 44045, 108355, 168979]
#
# 	18 Hospital_pk:  062017
# 	similarity:  0.005025125628140704
# 	signature matrix:  [85490, 57663, 325199, 11578, 137834, 584503, 283123, 15488, 395380, 19502]
#
# 	19 Hospital_pk:  240018
# 	similarity:  0.0
# 	signature matrix:  [147432, 370819, 227560, 321688, 140665, 77347, 24777, 48045, 61873, 695102]
#
# 	20 Hospital_pk:  420078
# 	similarity:  0.0
# 	signature matrix:  [46407, 208660, 102100, 241692, 227628, 28879, 3645, 104339, 45799, 196313]
